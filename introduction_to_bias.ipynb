# %% [markdown]
# # 0. Environment Setup
#
# - Please run the code below at the start. It fetches the bias tool from GitHub, and installs a missing package.

# %%
# RUN THE FOLLOWING ONCE AT THE START, IN GOOGLE COLLAB
# !git clone https://github.com/robertcinca/bias_ml_study
# %cd "/content/bias_ml_study"
# !pip install chart-studio==1.1.0

# %% [markdown]
# # 1. Introduction & Instructions
#
# This study introduces you to Bias in Machine Learning (ML) whilst interacting with a bias mitigation tool. Some code is already provided. You can simply run these code snippets, however, please read them, including the comments. Please note that some cells take up to 8 minutes to run.
#
# As you go through the tutorial, you will be asked to complete 11 mini exercises, these are bolded and start with the word **Exercise**. There is an optional 12th exploratory exercise at the end. Please write answers down within this notebook and share the file with us in advance of the interview.
#
# The purpose of this activity is for us to understand how Bias is perceived within ML, and how to design tutorials and tools for Bias detection and mitigation. It is not to evaluate your ability or skills!
#
# Please note that Colab has some limitations: a session ends after 12 hours, or if it has been idle for more than 90 minutes. All runtime data is lost once the session ends. Therefore, you may want to complete this study in one go.
#
# To display all sections of the study, in the menubar at the top please "view" and then "expand sections".

# %% [markdown]
# **Exercise 1:** How would you describe what bias in machine learning is? Please write down your thoughts.

# %% [markdown]
# *Please single (or double) click this box and type your answer here.*

# %% [markdown]
# **Exercise 2:** How do issues of bias and fairness influence the way you use (or the way you would use) ML technology in your work? Please write down your thoughts.

# %% [markdown]
# *Please single (or double) click this box and type your answer here.*

# %% [markdown]
# This section contains import statements and global variables used in the tutorial

# %%
import os
import cufflinks as cf
import numpy as np
import pandas as pd
import plotly.io as pio
from IPython.display import Image, display
from ipywidgets import interact, interact_manual

from ml_bias_explainability.compile_model_and_analysis import CompileModelAndAnalysis
from ml_bias_explainability.find_best_parameters import FindBestParameter
from ml_bias_explainability.helpers.helper import Helper
from ml_bias_explainability.run_tool_interaction import RunInteraction

cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

from google.colab import data_table # comment out if not running in Colab

data_table.enable_dataframe_formatter() # comment out if not running in Colab
pio.renderers.default = "colab" # comment out if not running in Colab
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # 2. Our First Dataset: COMPAS Recidivism Dataset
#
# We will introduce concepts of bias through the help of the COMPAS dataset. The input features in this dataset are used to determine the risk of recidivism (chance of re-offending) that a criminal defendant has. This dataset is widely used within Bias Analysis as an example of a biased dataset.

# %%
# Variables refering to folder locations for the COMPAS dataset are defined here
"""
Path to the dataset
"""
first_dataset_csv_path = "scripts/data/1_compass_recidivism/compas-scores-two-years.csv"

"""
List of columns that need to be removed from the dataset in the pre-processing stage
"""
first_dataset_columns_to_remove = Helper.read_yaml("scripts/data/1_compass_recidivism/columns_to_remove.yml")

"""
Output folder for the analysis. This can be accessed at a later stage, 
to avoid having to re-run everything.
"""
output_folder_location = "scripts/data/1_compass_recidivism/output"

# %% [markdown]
# ### Step 1: Loading & Understanding the Dataset
#
# The first step is to load and clean the dataset. Have a look at the code below to get an idea of the cleaning processes that take place, and the resulting dataframe

# %%
# Load and clean the dataset
def clean_dataset(csv_path, columns_to_remove):
    # The dataset used is taken from https://github.com/propublica/compas-analysis
    df = pd.read_csv(csv_path, index_col=0)

    # Based on propublica analysis, filter rows where COMPAS scoring and
    # arrest date weren't within 30 days of each other
    df = df[df.days_b_screening_arrest <= 30]
    df = df[df.days_b_screening_arrest >= -30]

    # get rid of columns that shouldn't be in the input model
    filtered_columns_to_remove = df.filter(columns_to_remove)
    df.drop(filtered_columns_to_remove, inplace=True, axis=1)

    # Ensure validity of inputs – No NaNs
    object_list, numeric_list = Helper.get_df_types_list(df)
    for column in object_list:
        df[column].fillna("", inplace=True)
    for column in numeric_list:
        df[column].fillna(-1, inplace=True)

    return df

recidivism_df = clean_dataset(first_dataset_csv_path, first_dataset_columns_to_remove)
recidivism_df
# Out:
#           sex  age          age_cat              race  juv_fel_count  \
# id
# 1        Male   69  Greater than 45             Other              0
# 3        Male   34          25 - 45  African-American              0
# 4        Male   24     Less than 25  African-American              0
# 7        Male   44          25 - 45             Other              0
# 8        Male   41          25 - 45         Caucasian              0
# ...       ...  ...              ...               ...            ...
# 10996    Male   23     Less than 25  African-American              0
# 10997    Male   23     Less than 25  African-American              0
# 10999    Male   57  Greater than 45             Other              0
# 11000  Female   33          25 - 45  African-American              0
# 11001  Female   23     Less than 25          Hispanic              0
#
#        juv_misd_count  juv_other_count  priors_count c_charge_degree  \
# id
# 1                   0                0             0               F
# 3                   0                0             0               F
# 4                   0                1             4               F
# 7                   0                0             0               M
# 8                   0                0            14               F
# ...               ...              ...           ...             ...
# 10996               0                0             0               F
# 10997               0                0             0               F
# 10999               0                0             0               F
# 11000               0                0             3               M
# 11001               0                0             2               F
#
#        two_year_recid
# id
# 1                   0
# 3                   1
# 4                   1
# 7                   0
# 8                   1
# ...               ...
# 10996               0
# 10997               0
# 10999               0
# 11000               0
# 11001               1
#
# [6172 rows x 10 columns]

# %% [markdown]
# Here is a brief explanation of each feature:
# - sex: Male or Female
# - age: ranges from 18 to 96
# - age_cat: ages grouped into 3 categories: [Greater than 45, 25 - 45, Less than 25]
# - race: 6 categories: [Other, African-American, Caucasian, Hispanic, Asian, Native American]
# - juv_fel_count: number of felonies (serious offences) that the person committed as a juvenile (under 18). Ranges from 0 to 20.
# - juv_misd_count: number of misdemeanors (less serious offences) that the person committed as a juvenile (under 18). Ranges from 0 to 13.
# - juv_other_count: number of other charges (not felonies nor misdemeanors) that the person committed as a juvenile (under 18). Ranges from 0 to 9.
# - priors_count: number of previous offences that the person has committed. Ranges from 0 to 38.
# - c_charge_degree: whether the crime in question is a felony (F) or misdemeanor (M).
# - c_charge_desc: a description of the crime that took place
#
# - two_year_recid (output feature): whether the person in question went on to commit a crime within the next two years. 1 for yes, 0 for no.

# %% [markdown]
# **Exercise 3:** From the 10 input features of the dataset, which features would you say could be problematic in terms of bias and discrimination? In other words, if you were building a model with this dataset, what features would you expect to cause bias?

# %% [markdown]
# *Please single (or double) click this box and type your answer here.*

# %% [markdown]
# Before even starting on any computations, it is worth playing around with the dataset to get a feel for it. Feel free to use the next few sections to explore the dataset

# %%
# Interact with specification of arguments
@interact
def show_filtered_raw_data(column=recidivism_df.select_dtypes(include=[np.number]).columns, x=(0, 100, 1)):
    return recidivism_df.loc[recidivism_df[column] >= x]
# Out:
# interactive(children=(Dropdown(description='column', options=('age', 'juv_fel_count', 'juv_misd_count', 'juv_o…

# %%
# Observe the data through a scatter plot. Press "Run Interact" to start the plotting.
@interact_manual
def scatter_plot(
    x=list(recidivism_df.select_dtypes("number").columns),
    y=list(recidivism_df.select_dtypes("number").columns)[1:],
    theme=list(cf.themes.THEMES.keys()),
    colorscale=list(cf.colors._scales_names.keys()),
):

    recidivism_df.iplot(
        kind="scatter",
        x=x,
        y=y,
        mode="markers",
        xTitle=x.title(),
        yTitle=y.title(),
        title=f"Scatter Plot: {y.title()} vs {x.title()}",
        theme=theme,
        colorscale=colorscale,
    )
# Out:
# interactive(children=(Dropdown(description='x', options=('age', 'juv_fel_count', 'juv_misd_count', 'juv_other_…

# %% [markdown]
# Please note, if you want to look at any of the csv files in-depth (e.g., by opening them in Excel), feel free to do so. You can find them under the following directory: ``ml_bias_explainability/scripts/data/``. E.g., the COMPAS dataset that you have just been looking at is located at ``ml_bias_explainability/scripts/data/1_compass_recidivism/compas-scores-two-years.csv``. In there you will also see an ``output`` folder, which is where all the computed analysis goes.

# %% [markdown]
# ### Step 2: Computing the Analysis
# The second step is to use the tool to create a ML model and then compute bias statistics and visualizations related to the output. Bias concepts and definitions will be explained and inspected in the Tool Analysis section (Section 3).

# %%
# Firstly define the following parameters for the tool

"""
training_types tells the bias tool what modifications to apply to the dataset before running the analysis.
There are two types: original_dataset, which leaves the data unchanged and remove_feature, which runs 
the analysis on multiple datasets, each dataset having a different feature removed.
"""
training_types = [
        "original_dataset",
        "remove_feature",
    ]

"""
features_of_interest are user-defined input features that are at risk of bias or discrimination. 
The "all" setting shows the overall metrics for the dataset.
"""
features_of_interest = ["all", "race", "sex", "age_cat"]

"""
This defines the output feature, the rest of the features will be deemed as input features.
"""
output = "two_year_recid"

"""
This is a threshold for the tool to use when defining categorical vs numerical features. 
Keeping this value low will make the analysis run faster, at the expense of granularity.
"""
unique_values = 6

"""
Setting Verbose to True will result in additional textual explanations highlighting areas with potential bias.
"""
verbose = False

"""
Setting parameters for the trained Neural Network model.
"""
best_params = dict(
    batch_size=128,
    epochs=15,
    optimizer="Nadam",
    init_mode="he_uniform",
    activation="sigmoid",
    weight_constraint=1,
    dropout_rate=0.2,
    neurons=128,
    hidden_layers=4,
)

# %%
# Running the analysis itself
(
    model_evaluation_df,
    raw_predictions_df,
    predictions_change_df,
    volatility_df,
    sensitivity_evaluation_df,
) = CompileModelAndAnalysis(
    training_types,
    features_of_interest,
    output,
    first_dataset_columns_to_remove,
    first_dataset_csv_path,
    None,
    unique_values,
    best_params,
).main(
    recidivism_df
)
# Out:
# RUNNING ANALYSIS FOR TRAINING TYPE: 'original_dataset'
#
# List of numeric features for this dataset: ['age', 'juv_fel_count', 'juv_misd_count', 'juv_other_count', 'priors_count']
# List of non-numeric features: ['sex', 'age_cat', 'race', 'c_charge_degree']
#
# Training the model:
# Epoch 1/15
# 29/29 [==============================] - 3s 41ms/step - loss: 0.7138 - false_negatives: 1158.0000 - false_positives: 655.0000 - true_negatives: 1393.0000 - true_positives: 496.0000 - accuracy: 0.5103 - precision: 0.4309 - recall: 0.2999 - val_loss: 0.6886 - val_false_negatives: 573.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 662.0000 - val_true_positives: 0.0000e+00 - val_accuracy: 0.5360 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6974 - false_negatives: 1209.0000 - false_positives: 549.0000 - true_negatives: 1499.0000 - true_positives: 445.0000 - accuracy: 0.5251 - precision: 0.4477 - recall: 0.2690 - val_loss: 0.6784 - val_false_negatives: 526.0000 - val_false_positives: 14.0000 - val_true_negatives: 648.0000 - val_true_positives: 47.0000 - val_accuracy: 0.5628 - val_precision: 0.7705 - val_recall: 0.0820
# Epoch 3/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6666 - false_negatives: 1073.0000 - false_positives: 428.0000 - true_negatives: 1620.0000 - true_positives: 581.0000 - accuracy: 0.5945 - precision: 0.5758 - recall: 0.3513 - val_loss: 0.6427 - val_false_negatives: 321.0000 - val_false_positives: 128.0000 - val_true_negatives: 534.0000 - val_true_positives: 252.0000 - val_accuracy: 0.6364 - val_precision: 0.6632 - val_recall: 0.4398
# Epoch 4/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6235 - false_negatives: 806.0000 - false_positives: 490.0000 - true_negatives: 1558.0000 - true_positives: 848.0000 - accuracy: 0.6499 - precision: 0.6338 - recall: 0.5127 - val_loss: 0.6327 - val_false_negatives: 238.0000 - val_false_positives: 196.0000 - val_true_negatives: 466.0000 - val_true_positives: 335.0000 - val_accuracy: 0.6486 - val_precision: 0.6309 - val_recall: 0.5846
# Epoch 5/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6165 - false_negatives: 747.0000 - false_positives: 467.0000 - true_negatives: 1581.0000 - true_positives: 907.0000 - accuracy: 0.6721 - precision: 0.6601 - recall: 0.5484 - val_loss: 0.6303 - val_false_negatives: 253.0000 - val_false_positives: 171.0000 - val_true_negatives: 491.0000 - val_true_positives: 320.0000 - val_accuracy: 0.6567 - val_precision: 0.6517 - val_recall: 0.5585
# Epoch 6/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6079 - false_negatives: 747.0000 - false_positives: 469.0000 - true_negatives: 1579.0000 - true_positives: 907.0000 - accuracy: 0.6715 - precision: 0.6592 - recall: 0.5484 - val_loss: 0.6281 - val_false_negatives: 246.0000 - val_false_positives: 180.0000 - val_true_negatives: 482.0000 - val_true_positives: 327.0000 - val_accuracy: 0.6551 - val_precision: 0.6450 - val_recall: 0.5707
# Epoch 7/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6062 - false_negatives: 734.0000 - false_positives: 455.0000 - true_negatives: 1593.0000 - true_positives: 920.0000 - accuracy: 0.6788 - precision: 0.6691 - recall: 0.5562 - val_loss: 0.6265 - val_false_negatives: 252.0000 - val_false_positives: 173.0000 - val_true_negatives: 489.0000 - val_true_positives: 321.0000 - val_accuracy: 0.6559 - val_precision: 0.6498 - val_recall: 0.5602
# Epoch 8/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6045 - false_negatives: 735.0000 - false_positives: 451.0000 - true_negatives: 1597.0000 - true_positives: 919.0000 - accuracy: 0.6796 - precision: 0.6708 - recall: 0.5556 - val_loss: 0.6252 - val_false_negatives: 256.0000 - val_false_positives: 172.0000 - val_true_negatives: 490.0000 - val_true_positives: 317.0000 - val_accuracy: 0.6534 - val_precision: 0.6483 - val_recall: 0.5532
# Epoch 9/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6032 - false_negatives: 719.0000 - false_positives: 445.0000 - true_negatives: 1603.0000 - true_positives: 935.0000 - accuracy: 0.6856 - precision: 0.6775 - recall: 0.5653 - val_loss: 0.6243 - val_false_negatives: 247.0000 - val_false_positives: 180.0000 - val_true_negatives: 482.0000 - val_true_positives: 326.0000 - val_accuracy: 0.6543 - val_precision: 0.6443 - val_recall: 0.5689
# Epoch 10/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6056 - false_negatives: 719.0000 - false_positives: 436.0000 - true_negatives: 1612.0000 - true_positives: 935.0000 - accuracy: 0.6880 - precision: 0.6820 - recall: 0.5653 - val_loss: 0.6238 - val_false_negatives: 246.0000 - val_false_positives: 180.0000 - val_true_negatives: 482.0000 - val_true_positives: 327.0000 - val_accuracy: 0.6551 - val_precision: 0.6450 - val_recall: 0.5707
# Epoch 11/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6043 - false_negatives: 724.0000 - false_positives: 461.0000 - true_negatives: 1587.0000 - true_positives: 930.0000 - accuracy: 0.6799 - precision: 0.6686 - recall: 0.5623 - val_loss: 0.6230 - val_false_negatives: 249.0000 - val_false_positives: 178.0000 - val_true_negatives: 484.0000 - val_true_positives: 324.0000 - val_accuracy: 0.6543 - val_precision: 0.6454 - val_recall: 0.5654
# Epoch 12/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6034 - false_negatives: 712.0000 - false_positives: 450.0000 - true_negatives: 1598.0000 - true_positives: 942.0000 - accuracy: 0.6861 - precision: 0.6767 - recall: 0.5695 - val_loss: 0.6227 - val_false_negatives: 241.0000 - val_false_positives: 184.0000 - val_true_negatives: 478.0000 - val_true_positives: 332.0000 - val_accuracy: 0.6559 - val_precision: 0.6434 - val_recall: 0.5794
# Epoch 13/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6004 - false_negatives: 705.0000 - false_positives: 463.0000 - true_negatives: 1585.0000 - true_positives: 949.0000 - accuracy: 0.6845 - precision: 0.6721 - recall: 0.5738 - val_loss: 0.6224 - val_false_negatives: 247.0000 - val_false_positives: 181.0000 - val_true_negatives: 481.0000 - val_true_positives: 326.0000 - val_accuracy: 0.6534 - val_precision: 0.6430 - val_recall: 0.5689
# Epoch 14/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6015 - false_negatives: 714.0000 - false_positives: 451.0000 - true_negatives: 1597.0000 - true_positives: 940.0000 - accuracy: 0.6853 - precision: 0.6758 - recall: 0.5683 - val_loss: 0.6221 - val_false_negatives: 235.0000 - val_false_positives: 184.0000 - val_true_negatives: 478.0000 - val_true_positives: 338.0000 - val_accuracy: 0.6607 - val_precision: 0.6475 - val_recall: 0.5899
# Epoch 15/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6000 - false_negatives: 700.0000 - false_positives: 457.0000 - true_negatives: 1591.0000 - true_positives: 954.0000 - accuracy: 0.6875 - precision: 0.6761 - recall: 0.5768 - val_loss: 0.6221 - val_false_negatives: 236.0000 - val_false_positives: 184.0000 - val_true_negatives: 478.0000 - val_true_positives: 337.0000 - val_accuracy: 0.6599 - val_precision: 0.6468 - val_recall: 0.5881
# 10/10 [==============================] - 0s 18ms/step
# 10/10 [==============================] - 0s 19ms/step
# 10/10 [==============================] - 0s 19ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 10/10 [==============================] - 0s 5ms/step
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 5ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.9s finished
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_sex'
#
# List of numeric features for this dataset: ['age', 'juv_fel_count', 'juv_misd_count', 'juv_other_count', 'priors_count']
# List of non-numeric features: ['age_cat', 'race', 'c_charge_degree']
#
# Training the model:
# Epoch 1/15
# 29/29 [==============================] - 3s 40ms/step - loss: 0.7024 - false_negatives_1: 1223.0000 - false_positives_1: 509.0000 - true_negatives_1: 1539.0000 - true_positives_1: 431.0000 - accuracy: 0.5321 - precision_1: 0.4585 - recall_1: 0.2606 - val_loss: 0.6897 - val_false_negatives_1: 573.0000 - val_false_positives_1: 0.0000e+00 - val_true_negatives_1: 662.0000 - val_true_positives_1: 0.0000e+00 - val_accuracy: 0.5360 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6969 - false_negatives_1: 1209.0000 - false_positives_1: 536.0000 - true_negatives_1: 1512.0000 - true_positives_1: 445.0000 - accuracy: 0.5286 - precision_1: 0.4536 - recall_1: 0.2690 - val_loss: 0.6860 - val_false_negatives_1: 573.0000 - val_false_positives_1: 0.0000e+00 - val_true_negatives_1: 662.0000 - val_true_positives_1: 0.0000e+00 - val_accuracy: 0.5360 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6860 - false_negatives_1: 1200.0000 - false_positives_1: 427.0000 - true_negatives_1: 1621.0000 - true_positives_1: 454.0000 - accuracy: 0.5605 - precision_1: 0.5153 - recall_1: 0.2745 - val_loss: 0.6626 - val_false_negatives_1: 363.0000 - val_false_positives_1: 97.0000 - val_true_negatives_1: 565.0000 - val_true_positives_1: 210.0000 - val_accuracy: 0.6275 - val_precision_1: 0.6840 - val_recall_1: 0.3665
# Epoch 4/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6366 - false_negatives_1: 888.0000 - false_positives_1: 443.0000 - true_negatives_1: 1605.0000 - true_positives_1: 766.0000 - accuracy: 0.6405 - precision_1: 0.6336 - recall_1: 0.4631 - val_loss: 0.6346 - val_false_negatives_1: 250.0000 - val_false_positives_1: 189.0000 - val_true_negatives_1: 473.0000 - val_true_positives_1: 323.0000 - val_accuracy: 0.6445 - val_precision_1: 0.6309 - val_recall_1: 0.5637
# Epoch 5/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6131 - false_negatives_1: 723.0000 - false_positives_1: 485.0000 - true_negatives_1: 1563.0000 - true_positives_1: 931.0000 - accuracy: 0.6737 - precision_1: 0.6575 - recall_1: 0.5629 - val_loss: 0.6319 - val_false_negatives_1: 241.0000 - val_false_positives_1: 193.0000 - val_true_negatives_1: 469.0000 - val_true_positives_1: 332.0000 - val_accuracy: 0.6486 - val_precision_1: 0.6324 - val_recall_1: 0.5794
# Epoch 6/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6134 - false_negatives_1: 718.0000 - false_positives_1: 468.0000 - true_negatives_1: 1580.0000 - true_positives_1: 936.0000 - accuracy: 0.6796 - precision_1: 0.6667 - recall_1: 0.5659 - val_loss: 0.6293 - val_false_negatives_1: 245.0000 - val_false_positives_1: 195.0000 - val_true_negatives_1: 467.0000 - val_true_positives_1: 328.0000 - val_accuracy: 0.6437 - val_precision_1: 0.6272 - val_recall_1: 0.5724
# Epoch 7/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6096 - false_negatives_1: 743.0000 - false_positives_1: 434.0000 - true_negatives_1: 1614.0000 - true_positives_1: 911.0000 - accuracy: 0.6821 - precision_1: 0.6773 - recall_1: 0.5508 - val_loss: 0.6277 - val_false_negatives_1: 247.0000 - val_false_positives_1: 193.0000 - val_true_negatives_1: 469.0000 - val_true_positives_1: 326.0000 - val_accuracy: 0.6437 - val_precision_1: 0.6281 - val_recall_1: 0.5689
# Epoch 8/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6058 - false_negatives_1: 716.0000 - false_positives_1: 452.0000 - true_negatives_1: 1596.0000 - true_positives_1: 938.0000 - accuracy: 0.6845 - precision_1: 0.6748 - recall_1: 0.5671 - val_loss: 0.6261 - val_false_negatives_1: 261.0000 - val_false_positives_1: 180.0000 - val_true_negatives_1: 482.0000 - val_true_positives_1: 312.0000 - val_accuracy: 0.6429 - val_precision_1: 0.6341 - val_recall_1: 0.5445
# Epoch 9/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6041 - false_negatives_1: 721.0000 - false_positives_1: 449.0000 - true_negatives_1: 1599.0000 - true_positives_1: 933.0000 - accuracy: 0.6840 - precision_1: 0.6751 - recall_1: 0.5641 - val_loss: 0.6255 - val_false_negatives_1: 253.0000 - val_false_positives_1: 188.0000 - val_true_negatives_1: 474.0000 - val_true_positives_1: 320.0000 - val_accuracy: 0.6429 - val_precision_1: 0.6299 - val_recall_1: 0.5585
# Epoch 10/15
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6054 - false_negatives_1: 725.0000 - false_positives_1: 465.0000 - true_negatives_1: 1583.0000 - true_positives_1: 929.0000 - accuracy: 0.6786 - precision_1: 0.6664 - recall_1: 0.5617 - val_loss: 0.6243 - val_false_negatives_1: 261.0000 - val_false_positives_1: 183.0000 - val_true_negatives_1: 479.0000 - val_true_positives_1: 312.0000 - val_accuracy: 0.6405 - val_precision_1: 0.6303 - val_recall_1: 0.5445
# Epoch 11/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6038 - false_negatives_1: 715.0000 - false_positives_1: 461.0000 - true_negatives_1: 1587.0000 - true_positives_1: 939.0000 - accuracy: 0.6823 - precision_1: 0.6707 - recall_1: 0.5677 - val_loss: 0.6237 - val_false_negatives_1: 251.0000 - val_false_positives_1: 187.0000 - val_true_negatives_1: 475.0000 - val_true_positives_1: 322.0000 - val_accuracy: 0.6453 - val_precision_1: 0.6326 - val_recall_1: 0.5620
# Epoch 12/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6023 - false_negatives_1: 700.0000 - false_positives_1: 472.0000 - true_negatives_1: 1576.0000 - true_positives_1: 954.0000 - accuracy: 0.6834 - precision_1: 0.6690 - recall_1: 0.5768 - val_loss: 0.6234 - val_false_negatives_1: 255.0000 - val_false_positives_1: 187.0000 - val_true_negatives_1: 475.0000 - val_true_positives_1: 318.0000 - val_accuracy: 0.6421 - val_precision_1: 0.6297 - val_recall_1: 0.5550
# Epoch 13/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6025 - false_negatives_1: 703.0000 - false_positives_1: 441.0000 - true_negatives_1: 1607.0000 - true_positives_1: 951.0000 - accuracy: 0.6910 - precision_1: 0.6832 - recall_1: 0.5750 - val_loss: 0.6233 - val_false_negatives_1: 246.0000 - val_false_positives_1: 194.0000 - val_true_negatives_1: 468.0000 - val_true_positives_1: 327.0000 - val_accuracy: 0.6437 - val_precision_1: 0.6276 - val_recall_1: 0.5707
# Epoch 14/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6016 - false_negatives_1: 705.0000 - false_positives_1: 460.0000 - true_negatives_1: 1588.0000 - true_positives_1: 949.0000 - accuracy: 0.6853 - precision_1: 0.6735 - recall_1: 0.5738 - val_loss: 0.6231 - val_false_negatives_1: 239.0000 - val_false_positives_1: 200.0000 - val_true_negatives_1: 462.0000 - val_true_positives_1: 334.0000 - val_accuracy: 0.6445 - val_precision_1: 0.6255 - val_recall_1: 0.5829
# Epoch 15/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6002 - false_negatives_1: 703.0000 - false_positives_1: 461.0000 - true_negatives_1: 1587.0000 - true_positives_1: 951.0000 - accuracy: 0.6856 - precision_1: 0.6735 - recall_1: 0.5750 - val_loss: 0.6227 - val_false_negatives_1: 254.0000 - val_false_positives_1: 183.0000 - val_true_negatives_1: 479.0000 - val_true_positives_1: 319.0000 - val_accuracy: 0.6462 - val_precision_1: 0.6355 - val_recall_1: 0.5567
# 10/10 [==============================] - 0s 19ms/step
# 10/10 [==============================] - 0s 18ms/step
# 10/10 [==============================] - 0s 21ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.4s finished
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_age'
#
# List of numeric features for this dataset: ['juv_fel_count', 'juv_misd_count', 'juv_other_count', 'priors_count']
# List of non-numeric features: ['sex', 'age_cat', 'race', 'c_charge_degree']
#
# Training the model:
# Epoch 1/15
# 29/29 [==============================] - 3s 41ms/step - loss: 0.7029 - false_negatives_2: 1204.0000 - false_positives_2: 517.0000 - true_negatives_2: 1531.0000 - true_positives_2: 450.0000 - accuracy: 0.5351 - precision_2: 0.4654 - recall_2: 0.2721 - val_loss: 0.6885 - val_false_negatives_2: 573.0000 - val_false_positives_2: 0.0000e+00 - val_true_negatives_2: 662.0000 - val_true_positives_2: 0.0000e+00 - val_accuracy: 0.5360 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6930 - false_negatives_2: 1196.0000 - false_positives_2: 499.0000 - true_negatives_2: 1549.0000 - true_positives_2: 458.0000 - accuracy: 0.5421 - precision_2: 0.4786 - recall_2: 0.2769 - val_loss: 0.6795 - val_false_negatives_2: 518.0000 - val_false_positives_2: 20.0000 - val_true_negatives_2: 642.0000 - val_true_positives_2: 55.0000 - val_accuracy: 0.5644 - val_precision_2: 0.7333 - val_recall_2: 0.0960
# Epoch 3/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6646 - false_negatives_2: 1043.0000 - false_positives_2: 429.0000 - true_negatives_2: 1619.0000 - true_positives_2: 611.0000 - accuracy: 0.6024 - precision_2: 0.5875 - recall_2: 0.3694 - val_loss: 0.6478 - val_false_negatives_2: 351.0000 - val_false_positives_2: 103.0000 - val_true_negatives_2: 559.0000 - val_true_positives_2: 222.0000 - val_accuracy: 0.6324 - val_precision_2: 0.6831 - val_recall_2: 0.3874
# Epoch 4/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6300 - false_negatives_2: 834.0000 - false_positives_2: 453.0000 - true_negatives_2: 1595.0000 - true_positives_2: 820.0000 - accuracy: 0.6524 - precision_2: 0.6441 - recall_2: 0.4958 - val_loss: 0.6377 - val_false_negatives_2: 279.0000 - val_false_positives_2: 172.0000 - val_true_negatives_2: 490.0000 - val_true_positives_2: 294.0000 - val_accuracy: 0.6348 - val_precision_2: 0.6309 - val_recall_2: 0.5131
# Epoch 5/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6216 - false_negatives_2: 799.0000 - false_positives_2: 450.0000 - true_negatives_2: 1598.0000 - true_positives_2: 855.0000 - accuracy: 0.6626 - precision_2: 0.6552 - recall_2: 0.5169 - val_loss: 0.6361 - val_false_negatives_2: 262.0000 - val_false_positives_2: 182.0000 - val_true_negatives_2: 480.0000 - val_true_positives_2: 311.0000 - val_accuracy: 0.6405 - val_precision_2: 0.6308 - val_recall_2: 0.5428
# Epoch 6/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6141 - false_negatives_2: 770.0000 - false_positives_2: 462.0000 - true_negatives_2: 1586.0000 - true_positives_2: 884.0000 - accuracy: 0.6672 - precision_2: 0.6568 - recall_2: 0.5345 - val_loss: 0.6335 - val_false_negatives_2: 263.0000 - val_false_positives_2: 178.0000 - val_true_negatives_2: 484.0000 - val_true_positives_2: 310.0000 - val_accuracy: 0.6429 - val_precision_2: 0.6352 - val_recall_2: 0.5410
# Epoch 7/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6109 - false_negatives_2: 756.0000 - false_positives_2: 448.0000 - true_negatives_2: 1600.0000 - true_positives_2: 898.0000 - accuracy: 0.6748 - precision_2: 0.6672 - recall_2: 0.5429 - val_loss: 0.6314 - val_false_negatives_2: 268.0000 - val_false_positives_2: 165.0000 - val_true_negatives_2: 497.0000 - val_true_positives_2: 305.0000 - val_accuracy: 0.6494 - val_precision_2: 0.6489 - val_recall_2: 0.5323
# Epoch 8/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6122 - false_negatives_2: 747.0000 - false_positives_2: 429.0000 - true_negatives_2: 1619.0000 - true_positives_2: 907.0000 - accuracy: 0.6823 - precision_2: 0.6789 - recall_2: 0.5484 - val_loss: 0.6303 - val_false_negatives_2: 269.0000 - val_false_positives_2: 164.0000 - val_true_negatives_2: 498.0000 - val_true_positives_2: 304.0000 - val_accuracy: 0.6494 - val_precision_2: 0.6496 - val_recall_2: 0.5305
# Epoch 9/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6107 - false_negatives_2: 745.0000 - false_positives_2: 449.0000 - true_negatives_2: 1599.0000 - true_positives_2: 909.0000 - accuracy: 0.6775 - precision_2: 0.6694 - recall_2: 0.5496 - val_loss: 0.6288 - val_false_negatives_2: 254.0000 - val_false_positives_2: 173.0000 - val_true_negatives_2: 489.0000 - val_true_positives_2: 319.0000 - val_accuracy: 0.6543 - val_precision_2: 0.6484 - val_recall_2: 0.5567
# Epoch 10/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6097 - false_negatives_2: 752.0000 - false_positives_2: 457.0000 - true_negatives_2: 1591.0000 - true_positives_2: 902.0000 - accuracy: 0.6734 - precision_2: 0.6637 - recall_2: 0.5453 - val_loss: 0.6281 - val_false_negatives_2: 266.0000 - val_false_positives_2: 167.0000 - val_true_negatives_2: 495.0000 - val_true_positives_2: 307.0000 - val_accuracy: 0.6494 - val_precision_2: 0.6477 - val_recall_2: 0.5358
# Epoch 11/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6060 - false_negatives_2: 747.0000 - false_positives_2: 457.0000 - true_negatives_2: 1591.0000 - true_positives_2: 907.0000 - accuracy: 0.6748 - precision_2: 0.6650 - recall_2: 0.5484 - val_loss: 0.6276 - val_false_negatives_2: 254.0000 - val_false_positives_2: 173.0000 - val_true_negatives_2: 489.0000 - val_true_positives_2: 319.0000 - val_accuracy: 0.6543 - val_precision_2: 0.6484 - val_recall_2: 0.5567
# Epoch 12/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6057 - false_negatives_2: 728.0000 - false_positives_2: 455.0000 - true_negatives_2: 1593.0000 - true_positives_2: 926.0000 - accuracy: 0.6804 - precision_2: 0.6705 - recall_2: 0.5599 - val_loss: 0.6274 - val_false_negatives_2: 253.0000 - val_false_positives_2: 174.0000 - val_true_negatives_2: 488.0000 - val_true_positives_2: 320.0000 - val_accuracy: 0.6543 - val_precision_2: 0.6478 - val_recall_2: 0.5585
# Epoch 13/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6034 - false_negatives_2: 701.0000 - false_positives_2: 449.0000 - true_negatives_2: 1599.0000 - true_positives_2: 953.0000 - accuracy: 0.6894 - precision_2: 0.6797 - recall_2: 0.5762 - val_loss: 0.6270 - val_false_negatives_2: 249.0000 - val_false_positives_2: 180.0000 - val_true_negatives_2: 482.0000 - val_true_positives_2: 324.0000 - val_accuracy: 0.6526 - val_precision_2: 0.6429 - val_recall_2: 0.5654
# Epoch 14/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6052 - false_negatives_2: 716.0000 - false_positives_2: 455.0000 - true_negatives_2: 1593.0000 - true_positives_2: 938.0000 - accuracy: 0.6837 - precision_2: 0.6734 - recall_2: 0.5671 - val_loss: 0.6268 - val_false_negatives_2: 249.0000 - val_false_positives_2: 180.0000 - val_true_negatives_2: 482.0000 - val_true_positives_2: 324.0000 - val_accuracy: 0.6526 - val_precision_2: 0.6429 - val_recall_2: 0.5654
# Epoch 15/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6043 - false_negatives_2: 699.0000 - false_positives_2: 458.0000 - true_negatives_2: 1590.0000 - true_positives_2: 955.0000 - accuracy: 0.6875 - precision_2: 0.6759 - recall_2: 0.5774 - val_loss: 0.6267 - val_false_negatives_2: 237.0000 - val_false_positives_2: 194.0000 - val_true_negatives_2: 468.0000 - val_true_positives_2: 336.0000 - val_accuracy: 0.6510 - val_precision_2: 0.6340 - val_recall_2: 0.5864
# 10/10 [==============================] - 0s 18ms/step
# 10/10 [==============================] - 0s 18ms/step
# 10/10 [==============================] - 0s 17ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 5ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 5ms/step
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.4s finished
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_age_cat'
#
# List of numeric features for this dataset: ['age', 'juv_fel_count', 'juv_misd_count', 'juv_other_count', 'priors_count']
# List of non-numeric features: ['sex', 'race', 'c_charge_degree']
#
# Training the model:
# Epoch 1/15
# 29/29 [==============================] - 3s 47ms/step - loss: 0.7002 - false_negatives_3: 1224.0000 - false_positives_3: 533.0000 - true_negatives_3: 1515.0000 - true_positives_3: 430.0000 - accuracy: 0.5254 - precision_3: 0.4465 - recall_3: 0.2600 - val_loss: 0.6876 - val_false_negatives_3: 573.0000 - val_false_positives_3: 0.0000e+00 - val_true_negatives_3: 662.0000 - val_true_positives_3: 0.0000e+00 - val_accuracy: 0.5360 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6923 - false_negatives_3: 1212.0000 - false_positives_3: 504.0000 - true_negatives_3: 1544.0000 - true_positives_3: 442.0000 - accuracy: 0.5365 - precision_3: 0.4672 - recall_3: 0.2672 - val_loss: 0.6732 - val_false_negatives_3: 462.0000 - val_false_positives_3: 37.0000 - val_true_negatives_3: 625.0000 - val_true_positives_3: 111.0000 - val_accuracy: 0.5960 - val_precision_3: 0.7500 - val_recall_3: 0.1937
# Epoch 3/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6556 - false_negatives_3: 1014.0000 - false_positives_3: 423.0000 - true_negatives_3: 1625.0000 - true_positives_3: 640.0000 - accuracy: 0.6118 - precision_3: 0.6021 - recall_3: 0.3869 - val_loss: 0.6372 - val_false_negatives_3: 290.0000 - val_false_positives_3: 156.0000 - val_true_negatives_3: 506.0000 - val_true_positives_3: 283.0000 - val_accuracy: 0.6389 - val_precision_3: 0.6446 - val_recall_3: 0.4939
# Epoch 4/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6180 - false_negatives_3: 782.0000 - false_positives_3: 456.0000 - true_negatives_3: 1592.0000 - true_positives_3: 872.0000 - accuracy: 0.6656 - precision_3: 0.6566 - recall_3: 0.5272 - val_loss: 0.6337 - val_false_negatives_3: 266.0000 - val_false_positives_3: 169.0000 - val_true_negatives_3: 493.0000 - val_true_positives_3: 307.0000 - val_accuracy: 0.6478 - val_precision_3: 0.6450 - val_recall_3: 0.5358
# Epoch 5/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6130 - false_negatives_3: 770.0000 - false_positives_3: 448.0000 - true_negatives_3: 1600.0000 - true_positives_3: 884.0000 - accuracy: 0.6710 - precision_3: 0.6637 - recall_3: 0.5345 - val_loss: 0.6310 - val_false_negatives_3: 259.0000 - val_false_positives_3: 175.0000 - val_true_negatives_3: 487.0000 - val_true_positives_3: 314.0000 - val_accuracy: 0.6486 - val_precision_3: 0.6421 - val_recall_3: 0.5480
# Epoch 6/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6099 - false_negatives_3: 752.0000 - false_positives_3: 436.0000 - true_negatives_3: 1612.0000 - true_positives_3: 902.0000 - accuracy: 0.6791 - precision_3: 0.6741 - recall_3: 0.5453 - val_loss: 0.6287 - val_false_negatives_3: 265.0000 - val_false_positives_3: 175.0000 - val_true_negatives_3: 487.0000 - val_true_positives_3: 308.0000 - val_accuracy: 0.6437 - val_precision_3: 0.6377 - val_recall_3: 0.5375
# Epoch 7/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6094 - false_negatives_3: 746.0000 - false_positives_3: 443.0000 - true_negatives_3: 1605.0000 - true_positives_3: 908.0000 - accuracy: 0.6788 - precision_3: 0.6721 - recall_3: 0.5490 - val_loss: 0.6270 - val_false_negatives_3: 252.0000 - val_false_positives_3: 178.0000 - val_true_negatives_3: 484.0000 - val_true_positives_3: 321.0000 - val_accuracy: 0.6518 - val_precision_3: 0.6433 - val_recall_3: 0.5602
# Epoch 8/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6062 - false_negatives_3: 717.0000 - false_positives_3: 434.0000 - true_negatives_3: 1614.0000 - true_positives_3: 937.0000 - accuracy: 0.6891 - precision_3: 0.6834 - recall_3: 0.5665 - val_loss: 0.6260 - val_false_negatives_3: 243.0000 - val_false_positives_3: 187.0000 - val_true_negatives_3: 475.0000 - val_true_positives_3: 330.0000 - val_accuracy: 0.6518 - val_precision_3: 0.6383 - val_recall_3: 0.5759
# Epoch 9/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6035 - false_negatives_3: 727.0000 - false_positives_3: 435.0000 - true_negatives_3: 1613.0000 - true_positives_3: 927.0000 - accuracy: 0.6861 - precision_3: 0.6806 - recall_3: 0.5605 - val_loss: 0.6251 - val_false_negatives_3: 239.0000 - val_false_positives_3: 188.0000 - val_true_negatives_3: 474.0000 - val_true_positives_3: 334.0000 - val_accuracy: 0.6543 - val_precision_3: 0.6398 - val_recall_3: 0.5829
# Epoch 10/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6038 - false_negatives_3: 727.0000 - false_positives_3: 451.0000 - true_negatives_3: 1597.0000 - true_positives_3: 927.0000 - accuracy: 0.6818 - precision_3: 0.6727 - recall_3: 0.5605 - val_loss: 0.6243 - val_false_negatives_3: 240.0000 - val_false_positives_3: 185.0000 - val_true_negatives_3: 477.0000 - val_true_positives_3: 333.0000 - val_accuracy: 0.6559 - val_precision_3: 0.6429 - val_recall_3: 0.5812
# Epoch 11/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6047 - false_negatives_3: 742.0000 - false_positives_3: 443.0000 - true_negatives_3: 1605.0000 - true_positives_3: 912.0000 - accuracy: 0.6799 - precision_3: 0.6731 - recall_3: 0.5514 - val_loss: 0.6233 - val_false_negatives_3: 259.0000 - val_false_positives_3: 169.0000 - val_true_negatives_3: 493.0000 - val_true_positives_3: 314.0000 - val_accuracy: 0.6534 - val_precision_3: 0.6501 - val_recall_3: 0.5480
# Epoch 12/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6034 - false_negatives_3: 725.0000 - false_positives_3: 425.0000 - true_negatives_3: 1623.0000 - true_positives_3: 929.0000 - accuracy: 0.6894 - precision_3: 0.6861 - recall_3: 0.5617 - val_loss: 0.6228 - val_false_negatives_3: 238.0000 - val_false_positives_3: 188.0000 - val_true_negatives_3: 474.0000 - val_true_positives_3: 335.0000 - val_accuracy: 0.6551 - val_precision_3: 0.6405 - val_recall_3: 0.5846
# Epoch 13/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6040 - false_negatives_3: 726.0000 - false_positives_3: 455.0000 - true_negatives_3: 1593.0000 - true_positives_3: 928.0000 - accuracy: 0.6810 - precision_3: 0.6710 - recall_3: 0.5611 - val_loss: 0.6223 - val_false_negatives_3: 240.0000 - val_false_positives_3: 187.0000 - val_true_negatives_3: 475.0000 - val_true_positives_3: 333.0000 - val_accuracy: 0.6543 - val_precision_3: 0.6404 - val_recall_3: 0.5812
# Epoch 14/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6019 - false_negatives_3: 735.0000 - false_positives_3: 431.0000 - true_negatives_3: 1617.0000 - true_positives_3: 919.0000 - accuracy: 0.6850 - precision_3: 0.6807 - recall_3: 0.5556 - val_loss: 0.6224 - val_false_negatives_3: 236.0000 - val_false_positives_3: 193.0000 - val_true_negatives_3: 469.0000 - val_true_positives_3: 337.0000 - val_accuracy: 0.6526 - val_precision_3: 0.6358 - val_recall_3: 0.5881
# Epoch 15/15
# 29/29 [==============================] - 1s 17ms/step - loss: 0.6006 - false_negatives_3: 721.0000 - false_positives_3: 439.0000 - true_negatives_3: 1609.0000 - true_positives_3: 933.0000 - accuracy: 0.6867 - precision_3: 0.6800 - recall_3: 0.5641 - val_loss: 0.6219 - val_false_negatives_3: 237.0000 - val_false_positives_3: 188.0000 - val_true_negatives_3: 474.0000 - val_true_positives_3: 336.0000 - val_accuracy: 0.6559 - val_precision_3: 0.6412 - val_recall_3: 0.5864
# 10/10 [==============================] - 0s 19ms/step
# 10/10 [==============================] - 0s 18ms/step
# 10/10 [==============================] - 0s 18ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.1s finished
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_race'
#
# List of numeric features for this dataset: ['age', 'juv_fel_count', 'juv_misd_count', 'juv_other_count', 'priors_count']
# List of non-numeric features: ['sex', 'age_cat', 'c_charge_degree']
#
# Training the model:
# Epoch 1/15
# 29/29 [==============================] - 4s 45ms/step - loss: 0.7428 - false_negatives_4: 965.0000 - false_positives_4: 843.0000 - true_negatives_4: 1205.0000 - true_positives_4: 689.0000 - accuracy: 0.5116 - precision_4: 0.4497 - recall_4: 0.4166 - val_loss: 0.6899 - val_false_negatives_4: 573.0000 - val_false_positives_4: 0.0000e+00 - val_true_negatives_4: 662.0000 - val_true_positives_4: 0.0000e+00 - val_accuracy: 0.5360 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.7008 - false_negatives_4: 1227.0000 - false_positives_4: 524.0000 - true_negatives_4: 1524.0000 - true_positives_4: 427.0000 - accuracy: 0.5270 - precision_4: 0.4490 - recall_4: 0.2582 - val_loss: 0.6874 - val_false_negatives_4: 573.0000 - val_false_positives_4: 0.0000e+00 - val_true_negatives_4: 662.0000 - val_true_positives_4: 0.0000e+00 - val_accuracy: 0.5360 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6943 - false_negatives_4: 1224.0000 - false_positives_4: 485.0000 - true_negatives_4: 1563.0000 - true_positives_4: 430.0000 - accuracy: 0.5384 - precision_4: 0.4699 - recall_4: 0.2600 - val_loss: 0.6797 - val_false_negatives_4: 527.0000 - val_false_positives_4: 14.0000 - val_true_negatives_4: 648.0000 - val_true_positives_4: 46.0000 - val_accuracy: 0.5619 - val_precision_4: 0.7667 - val_recall_4: 0.0803
# Epoch 4/15
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6741 - false_negatives_4: 1141.0000 - false_positives_4: 436.0000 - true_negatives_4: 1612.0000 - true_positives_4: 513.0000 - accuracy: 0.5740 - precision_4: 0.5406 - recall_4: 0.3102 - val_loss: 0.6529 - val_false_negatives_4: 369.0000 - val_false_positives_4: 92.0000 - val_true_negatives_4: 570.0000 - val_true_positives_4: 204.0000 - val_accuracy: 0.6267 - val_precision_4: 0.6892 - val_recall_4: 0.3560
# Epoch 5/15
# 29/29 [==============================] - 1s 21ms/step - loss: 0.6358 - false_negatives_4: 894.0000 - false_positives_4: 449.0000 - true_negatives_4: 1599.0000 - true_positives_4: 760.0000 - accuracy: 0.6372 - precision_4: 0.6286 - recall_4: 0.4595 - val_loss: 0.6289 - val_false_negatives_4: 251.0000 - val_false_positives_4: 183.0000 - val_true_negatives_4: 479.0000 - val_true_positives_4: 322.0000 - val_accuracy: 0.6486 - val_precision_4: 0.6376 - val_recall_4: 0.5620
# Epoch 6/15
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6152 - false_negatives_4: 738.0000 - false_positives_4: 482.0000 - true_negatives_4: 1566.0000 - true_positives_4: 916.0000 - accuracy: 0.6704 - precision_4: 0.6552 - recall_4: 0.5538 - val_loss: 0.6257 - val_false_negatives_4: 248.0000 - val_false_positives_4: 179.0000 - val_true_negatives_4: 483.0000 - val_true_positives_4: 325.0000 - val_accuracy: 0.6543 - val_precision_4: 0.6448 - val_recall_4: 0.5672
# Epoch 7/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6098 - false_negatives_4: 739.0000 - false_positives_4: 478.0000 - true_negatives_4: 1570.0000 - true_positives_4: 915.0000 - accuracy: 0.6713 - precision_4: 0.6569 - recall_4: 0.5532 - val_loss: 0.6239 - val_false_negatives_4: 245.0000 - val_false_positives_4: 178.0000 - val_true_negatives_4: 484.0000 - val_true_positives_4: 328.0000 - val_accuracy: 0.6575 - val_precision_4: 0.6482 - val_recall_4: 0.5724
# Epoch 8/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6101 - false_negatives_4: 745.0000 - false_positives_4: 464.0000 - true_negatives_4: 1584.0000 - true_positives_4: 909.0000 - accuracy: 0.6734 - precision_4: 0.6621 - recall_4: 0.5496 - val_loss: 0.6224 - val_false_negatives_4: 240.0000 - val_false_positives_4: 184.0000 - val_true_negatives_4: 478.0000 - val_true_positives_4: 333.0000 - val_accuracy: 0.6567 - val_precision_4: 0.6441 - val_recall_4: 0.5812
# Epoch 9/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6068 - false_negatives_4: 729.0000 - false_positives_4: 465.0000 - true_negatives_4: 1583.0000 - true_positives_4: 925.0000 - accuracy: 0.6775 - precision_4: 0.6655 - recall_4: 0.5593 - val_loss: 0.6213 - val_false_negatives_4: 238.0000 - val_false_positives_4: 184.0000 - val_true_negatives_4: 478.0000 - val_true_positives_4: 335.0000 - val_accuracy: 0.6583 - val_precision_4: 0.6455 - val_recall_4: 0.5846
# Epoch 10/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6043 - false_negatives_4: 716.0000 - false_positives_4: 452.0000 - true_negatives_4: 1596.0000 - true_positives_4: 938.0000 - accuracy: 0.6845 - precision_4: 0.6748 - recall_4: 0.5671 - val_loss: 0.6206 - val_false_negatives_4: 237.0000 - val_false_positives_4: 186.0000 - val_true_negatives_4: 476.0000 - val_true_positives_4: 336.0000 - val_accuracy: 0.6575 - val_precision_4: 0.6437 - val_recall_4: 0.5864
# Epoch 11/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6059 - false_negatives_4: 715.0000 - false_positives_4: 476.0000 - true_negatives_4: 1572.0000 - true_positives_4: 939.0000 - accuracy: 0.6783 - precision_4: 0.6636 - recall_4: 0.5677 - val_loss: 0.6201 - val_false_negatives_4: 228.0000 - val_false_positives_4: 192.0000 - val_true_negatives_4: 470.0000 - val_true_positives_4: 345.0000 - val_accuracy: 0.6599 - val_precision_4: 0.6425 - val_recall_4: 0.6021
# Epoch 12/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6041 - false_negatives_4: 704.0000 - false_positives_4: 453.0000 - true_negatives_4: 1595.0000 - true_positives_4: 950.0000 - accuracy: 0.6875 - precision_4: 0.6771 - recall_4: 0.5744 - val_loss: 0.6199 - val_false_negatives_4: 225.0000 - val_false_positives_4: 194.0000 - val_true_negatives_4: 468.0000 - val_true_positives_4: 348.0000 - val_accuracy: 0.6607 - val_precision_4: 0.6421 - val_recall_4: 0.6073
# Epoch 13/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6008 - false_negatives_4: 709.0000 - false_positives_4: 457.0000 - true_negatives_4: 1591.0000 - true_positives_4: 945.0000 - accuracy: 0.6850 - precision_4: 0.6740 - recall_4: 0.5713 - val_loss: 0.6195 - val_false_negatives_4: 233.0000 - val_false_positives_4: 185.0000 - val_true_negatives_4: 477.0000 - val_true_positives_4: 340.0000 - val_accuracy: 0.6615 - val_precision_4: 0.6476 - val_recall_4: 0.5934
# Epoch 14/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6010 - false_negatives_4: 708.0000 - false_positives_4: 453.0000 - true_negatives_4: 1595.0000 - true_positives_4: 946.0000 - accuracy: 0.6864 - precision_4: 0.6762 - recall_4: 0.5719 - val_loss: 0.6192 - val_false_negatives_4: 228.0000 - val_false_positives_4: 188.0000 - val_true_negatives_4: 474.0000 - val_true_positives_4: 345.0000 - val_accuracy: 0.6632 - val_precision_4: 0.6473 - val_recall_4: 0.6021
# Epoch 15/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6011 - false_negatives_4: 701.0000 - false_positives_4: 468.0000 - true_negatives_4: 1580.0000 - true_positives_4: 953.0000 - accuracy: 0.6842 - precision_4: 0.6707 - recall_4: 0.5762 - val_loss: 0.6189 - val_false_negatives_4: 232.0000 - val_false_positives_4: 185.0000 - val_true_negatives_4: 477.0000 - val_true_positives_4: 341.0000 - val_accuracy: 0.6623 - val_precision_4: 0.6483 - val_recall_4: 0.5951
# 10/10 [==============================] - 0s 21ms/step
# 10/10 [==============================] - 0s 17ms/step
# 10/10 [==============================] - 0s 17ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    1.8s finished
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_juv_fel_count'
#
# List of numeric features for this dataset: ['age', 'juv_misd_count', 'juv_other_count', 'priors_count']
# List of non-numeric features: ['sex', 'age_cat', 'race', 'c_charge_degree']
#
# Training the model:
# Epoch 1/15
# 29/29 [==============================] - 3s 39ms/step - loss: 0.7028 - false_negatives_5: 1174.0000 - false_positives_5: 521.0000 - true_negatives_5: 1527.0000 - true_positives_5: 480.0000 - accuracy: 0.5421 - precision_5: 0.4795 - recall_5: 0.2902 - val_loss: 0.6883 - val_false_negatives_5: 573.0000 - val_false_positives_5: 0.0000e+00 - val_true_negatives_5: 662.0000 - val_true_positives_5: 0.0000e+00 - val_accuracy: 0.5360 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6897 - false_negatives_5: 1149.0000 - false_positives_5: 512.0000 - true_negatives_5: 1536.0000 - true_positives_5: 505.0000 - accuracy: 0.5513 - precision_5: 0.4966 - recall_5: 0.3053 - val_loss: 0.6790 - val_false_negatives_5: 551.0000 - val_false_positives_5: 4.0000 - val_true_negatives_5: 658.0000 - val_true_positives_5: 22.0000 - val_accuracy: 0.5506 - val_precision_5: 0.8462 - val_recall_5: 0.0384
# Epoch 3/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6706 - false_negatives_5: 1041.0000 - false_positives_5: 480.0000 - true_negatives_5: 1568.0000 - true_positives_5: 613.0000 - accuracy: 0.5891 - precision_5: 0.5608 - recall_5: 0.3706 - val_loss: 0.6435 - val_false_negatives_5: 305.0000 - val_false_positives_5: 148.0000 - val_true_negatives_5: 514.0000 - val_true_positives_5: 268.0000 - val_accuracy: 0.6332 - val_precision_5: 0.6442 - val_recall_5: 0.4677
# Epoch 4/15
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6229 - false_negatives_5: 799.0000 - false_positives_5: 472.0000 - true_negatives_5: 1576.0000 - true_positives_5: 855.0000 - accuracy: 0.6567 - precision_5: 0.6443 - recall_5: 0.5169 - val_loss: 0.6318 - val_false_negatives_5: 255.0000 - val_false_positives_5: 184.0000 - val_true_negatives_5: 478.0000 - val_true_positives_5: 318.0000 - val_accuracy: 0.6445 - val_precision_5: 0.6335 - val_recall_5: 0.5550
# Epoch 5/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6142 - false_negatives_5: 753.0000 - false_positives_5: 481.0000 - true_negatives_5: 1567.0000 - true_positives_5: 901.0000 - accuracy: 0.6667 - precision_5: 0.6520 - recall_5: 0.5447 - val_loss: 0.6293 - val_false_negatives_5: 247.0000 - val_false_positives_5: 187.0000 - val_true_negatives_5: 475.0000 - val_true_positives_5: 326.0000 - val_accuracy: 0.6486 - val_precision_5: 0.6355 - val_recall_5: 0.5689
# Epoch 6/15
# 29/29 [==============================] - 1s 17ms/step - loss: 0.6081 - false_negatives_5: 738.0000 - false_positives_5: 462.0000 - true_negatives_5: 1586.0000 - true_positives_5: 916.0000 - accuracy: 0.6759 - precision_5: 0.6647 - recall_5: 0.5538 - val_loss: 0.6277 - val_false_negatives_5: 234.0000 - val_false_positives_5: 203.0000 - val_true_negatives_5: 459.0000 - val_true_positives_5: 339.0000 - val_accuracy: 0.6462 - val_precision_5: 0.6255 - val_recall_5: 0.5916
# Epoch 7/15
# ...
# Epoch 6/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6558 - false_negatives_8: 892.0000 - false_positives_8: 541.0000 - true_negatives_8: 1507.0000 - true_positives_8: 762.0000 - accuracy: 0.6129 - precision_8: 0.5848 - recall_8: 0.4607 - val_loss: 0.6659 - val_false_negatives_8: 297.0000 - val_false_positives_8: 203.0000 - val_true_negatives_8: 459.0000 - val_true_positives_8: 276.0000 - val_accuracy: 0.5951 - val_precision_8: 0.5762 - val_recall_8: 0.4817
# Epoch 7/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6465 - false_negatives_8: 883.0000 - false_positives_8: 522.0000 - true_negatives_8: 1526.0000 - true_positives_8: 771.0000 - accuracy: 0.6205 - precision_8: 0.5963 - recall_8: 0.4661 - val_loss: 0.6667 - val_false_negatives_8: 279.0000 - val_false_positives_8: 217.0000 - val_true_negatives_8: 445.0000 - val_true_positives_8: 294.0000 - val_accuracy: 0.5984 - val_precision_8: 0.5753 - val_recall_8: 0.5131
# Epoch 8/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6488 - false_negatives_8: 884.0000 - false_positives_8: 524.0000 - true_negatives_8: 1524.0000 - true_positives_8: 770.0000 - accuracy: 0.6197 - precision_8: 0.5951 - recall_8: 0.4655 - val_loss: 0.6664 - val_false_negatives_8: 284.0000 - val_false_positives_8: 214.0000 - val_true_negatives_8: 448.0000 - val_true_positives_8: 289.0000 - val_accuracy: 0.5968 - val_precision_8: 0.5746 - val_recall_8: 0.5044
# Epoch 9/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6488 - false_negatives_8: 872.0000 - false_positives_8: 513.0000 - true_negatives_8: 1535.0000 - true_positives_8: 782.0000 - accuracy: 0.6259 - precision_8: 0.6039 - recall_8: 0.4728 - val_loss: 0.6664 - val_false_negatives_8: 277.0000 - val_false_positives_8: 219.0000 - val_true_negatives_8: 443.0000 - val_true_positives_8: 296.0000 - val_accuracy: 0.5984 - val_precision_8: 0.5748 - val_recall_8: 0.5166
# Epoch 10/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6436 - false_negatives_8: 873.0000 - false_positives_8: 490.0000 - true_negatives_8: 1558.0000 - true_positives_8: 781.0000 - accuracy: 0.6318 - precision_8: 0.6145 - recall_8: 0.4722 - val_loss: 0.6670 - val_false_negatives_8: 282.0000 - val_false_positives_8: 216.0000 - val_true_negatives_8: 446.0000 - val_true_positives_8: 291.0000 - val_accuracy: 0.5968 - val_precision_8: 0.5740 - val_recall_8: 0.5079
# Epoch 11/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6472 - false_negatives_8: 869.0000 - false_positives_8: 504.0000 - true_negatives_8: 1544.0000 - true_positives_8: 785.0000 - accuracy: 0.6291 - precision_8: 0.6090 - recall_8: 0.4746 - val_loss: 0.6663 - val_false_negatives_8: 288.0000 - val_false_positives_8: 210.0000 - val_true_negatives_8: 452.0000 - val_true_positives_8: 285.0000 - val_accuracy: 0.5968 - val_precision_8: 0.5758 - val_recall_8: 0.4974
# Epoch 12/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6431 - false_negatives_8: 895.0000 - false_positives_8: 495.0000 - true_negatives_8: 1553.0000 - true_positives_8: 759.0000 - accuracy: 0.6245 - precision_8: 0.6053 - recall_8: 0.4589 - val_loss: 0.6667 - val_false_negatives_8: 290.0000 - val_false_positives_8: 207.0000 - val_true_negatives_8: 455.0000 - val_true_positives_8: 283.0000 - val_accuracy: 0.5976 - val_precision_8: 0.5776 - val_recall_8: 0.4939
# Epoch 13/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6467 - false_negatives_8: 883.0000 - false_positives_8: 501.0000 - true_negatives_8: 1547.0000 - true_positives_8: 771.0000 - accuracy: 0.6261 - precision_8: 0.6061 - recall_8: 0.4661 - val_loss: 0.6663 - val_false_negatives_8: 290.0000 - val_false_positives_8: 207.0000 - val_true_negatives_8: 455.0000 - val_true_positives_8: 283.0000 - val_accuracy: 0.5976 - val_precision_8: 0.5776 - val_recall_8: 0.4939
# Epoch 14/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6443 - false_negatives_8: 879.0000 - false_positives_8: 493.0000 - true_negatives_8: 1555.0000 - true_positives_8: 775.0000 - accuracy: 0.6294 - precision_8: 0.6112 - recall_8: 0.4686 - val_loss: 0.6661 - val_false_negatives_8: 290.0000 - val_false_positives_8: 207.0000 - val_true_negatives_8: 455.0000 - val_true_positives_8: 283.0000 - val_accuracy: 0.5976 - val_precision_8: 0.5776 - val_recall_8: 0.4939
# Epoch 15/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6431 - false_negatives_8: 887.0000 - false_positives_8: 496.0000 - true_negatives_8: 1552.0000 - true_positives_8: 767.0000 - accuracy: 0.6264 - precision_8: 0.6073 - recall_8: 0.4637 - val_loss: 0.6664 - val_false_negatives_8: 286.0000 - val_false_positives_8: 212.0000 - val_true_negatives_8: 450.0000 - val_true_positives_8: 287.0000 - val_accuracy: 0.5968 - val_precision_8: 0.5752 - val_recall_8: 0.5009
# 10/10 [==============================] - 0s 17ms/step
# 10/10 [==============================] - 0s 18ms/step
# 10/10 [==============================] - 0s 18ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 5ms/step
# 10/10 [==============================] - 0s 5ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 5ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.1s finished
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_c_charge_degree'
#
# List of numeric features for this dataset: ['age', 'juv_fel_count', 'juv_misd_count', 'juv_other_count', 'priors_count']
# List of non-numeric features: ['sex', 'age_cat', 'race']
#
# Training the model:
# Epoch 1/15
# 29/29 [==============================] - 3s 39ms/step - loss: 0.7054 - false_negatives_9: 1242.0000 - false_positives_9: 553.0000 - true_negatives_9: 1495.0000 - true_positives_9: 412.0000 - accuracy: 0.5151 - precision_9: 0.4269 - recall_9: 0.2491 - val_loss: 0.6868 - val_false_negatives_9: 573.0000 - val_false_positives_9: 0.0000e+00 - val_true_negatives_9: 662.0000 - val_true_positives_9: 0.0000e+00 - val_accuracy: 0.5360 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 2/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6857 - false_negatives_9: 1200.0000 - false_positives_9: 475.0000 - true_negatives_9: 1573.0000 - true_positives_9: 454.0000 - accuracy: 0.5475 - precision_9: 0.4887 - recall_9: 0.2745 - val_loss: 0.6697 - val_false_negatives_9: 472.0000 - val_false_positives_9: 35.0000 - val_true_negatives_9: 627.0000 - val_true_positives_9: 101.0000 - val_accuracy: 0.5895 - val_precision_9: 0.7426 - val_recall_9: 0.1763
# Epoch 3/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6500 - false_negatives_9: 976.0000 - false_positives_9: 428.0000 - true_negatives_9: 1620.0000 - true_positives_9: 678.0000 - accuracy: 0.6207 - precision_9: 0.6130 - recall_9: 0.4099 - val_loss: 0.6349 - val_false_negatives_9: 310.0000 - val_false_positives_9: 120.0000 - val_true_negatives_9: 542.0000 - val_true_positives_9: 263.0000 - val_accuracy: 0.6518 - val_precision_9: 0.6867 - val_recall_9: 0.4590
# Epoch 4/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6152 - false_negatives_9: 765.0000 - false_positives_9: 464.0000 - true_negatives_9: 1584.0000 - true_positives_9: 889.0000 - accuracy: 0.6680 - precision_9: 0.6571 - recall_9: 0.5375 - val_loss: 0.6298 - val_false_negatives_9: 259.0000 - val_false_positives_9: 171.0000 - val_true_negatives_9: 491.0000 - val_true_positives_9: 314.0000 - val_accuracy: 0.6518 - val_precision_9: 0.6474 - val_recall_9: 0.5480
# Epoch 5/15
# 29/29 [==============================] - 0s 16ms/step - loss: 0.6125 - false_negatives_9: 747.0000 - false_positives_9: 447.0000 - true_negatives_9: 1601.0000 - true_positives_9: 907.0000 - accuracy: 0.6775 - precision_9: 0.6699 - recall_9: 0.5484 - val_loss: 0.6276 - val_false_negatives_9: 259.0000 - val_false_positives_9: 171.0000 - val_true_negatives_9: 491.0000 - val_true_positives_9: 314.0000 - val_accuracy: 0.6518 - val_precision_9: 0.6474 - val_recall_9: 0.5480
# Epoch 6/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6070 - false_negatives_9: 754.0000 - false_positives_9: 439.0000 - true_negatives_9: 1609.0000 - true_positives_9: 900.0000 - accuracy: 0.6777 - precision_9: 0.6721 - recall_9: 0.5441 - val_loss: 0.6260 - val_false_negatives_9: 274.0000 - val_false_positives_9: 155.0000 - val_true_negatives_9: 507.0000 - val_true_positives_9: 299.0000 - val_accuracy: 0.6526 - val_precision_9: 0.6586 - val_recall_9: 0.5218
# Epoch 7/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6050 - false_negatives_9: 745.0000 - false_positives_9: 439.0000 - true_negatives_9: 1609.0000 - true_positives_9: 909.0000 - accuracy: 0.6802 - precision_9: 0.6743 - recall_9: 0.5496 - val_loss: 0.6247 - val_false_negatives_9: 262.0000 - val_false_positives_9: 169.0000 - val_true_negatives_9: 493.0000 - val_true_positives_9: 311.0000 - val_accuracy: 0.6510 - val_precision_9: 0.6479 - val_recall_9: 0.5428
# Epoch 8/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6043 - false_negatives_9: 730.0000 - false_positives_9: 449.0000 - true_negatives_9: 1599.0000 - true_positives_9: 924.0000 - accuracy: 0.6815 - precision_9: 0.6730 - recall_9: 0.5586 - val_loss: 0.6237 - val_false_negatives_9: 251.0000 - val_false_positives_9: 181.0000 - val_true_negatives_9: 481.0000 - val_true_positives_9: 322.0000 - val_accuracy: 0.6502 - val_precision_9: 0.6402 - val_recall_9: 0.5620
# Epoch 9/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6031 - false_negatives_9: 713.0000 - false_positives_9: 448.0000 - true_negatives_9: 1600.0000 - true_positives_9: 941.0000 - accuracy: 0.6864 - precision_9: 0.6775 - recall_9: 0.5689 - val_loss: 0.6230 - val_false_negatives_9: 252.0000 - val_false_positives_9: 175.0000 - val_true_negatives_9: 487.0000 - val_true_positives_9: 321.0000 - val_accuracy: 0.6543 - val_precision_9: 0.6472 - val_recall_9: 0.5602
# Epoch 10/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6042 - false_negatives_9: 721.0000 - false_positives_9: 436.0000 - true_negatives_9: 1612.0000 - true_positives_9: 933.0000 - accuracy: 0.6875 - precision_9: 0.6815 - recall_9: 0.5641 - val_loss: 0.6224 - val_false_negatives_9: 247.0000 - val_false_positives_9: 175.0000 - val_true_negatives_9: 487.0000 - val_true_positives_9: 326.0000 - val_accuracy: 0.6583 - val_precision_9: 0.6507 - val_recall_9: 0.5689
# Epoch 11/15
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6027 - false_negatives_9: 706.0000 - false_positives_9: 459.0000 - true_negatives_9: 1589.0000 - true_positives_9: 948.0000 - accuracy: 0.6853 - precision_9: 0.6738 - recall_9: 0.5732 - val_loss: 0.6220 - val_false_negatives_9: 244.0000 - val_false_positives_9: 182.0000 - val_true_negatives_9: 480.0000 - val_true_positives_9: 329.0000 - val_accuracy: 0.6551 - val_precision_9: 0.6438 - val_recall_9: 0.5742
# Epoch 12/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6047 - false_negatives_9: 700.0000 - false_positives_9: 435.0000 - true_negatives_9: 1613.0000 - true_positives_9: 954.0000 - accuracy: 0.6934 - precision_9: 0.6868 - recall_9: 0.5768 - val_loss: 0.6213 - val_false_negatives_9: 251.0000 - val_false_positives_9: 173.0000 - val_true_negatives_9: 489.0000 - val_true_positives_9: 322.0000 - val_accuracy: 0.6567 - val_precision_9: 0.6505 - val_recall_9: 0.5620
# Epoch 13/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6020 - false_negatives_9: 719.0000 - false_positives_9: 442.0000 - true_negatives_9: 1606.0000 - true_positives_9: 935.0000 - accuracy: 0.6864 - precision_9: 0.6790 - recall_9: 0.5653 - val_loss: 0.6214 - val_false_negatives_9: 250.0000 - val_false_positives_9: 173.0000 - val_true_negatives_9: 489.0000 - val_true_positives_9: 323.0000 - val_accuracy: 0.6575 - val_precision_9: 0.6512 - val_recall_9: 0.5637
# Epoch 14/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6012 - false_negatives_9: 708.0000 - false_positives_9: 443.0000 - true_negatives_9: 1605.0000 - true_positives_9: 946.0000 - accuracy: 0.6891 - precision_9: 0.6811 - recall_9: 0.5719 - val_loss: 0.6211 - val_false_negatives_9: 250.0000 - val_false_positives_9: 174.0000 - val_true_negatives_9: 488.0000 - val_true_positives_9: 323.0000 - val_accuracy: 0.6567 - val_precision_9: 0.6499 - val_recall_9: 0.5637
# Epoch 15/15
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6011 - false_negatives_9: 710.0000 - false_positives_9: 447.0000 - true_negatives_9: 1601.0000 - true_positives_9: 944.0000 - accuracy: 0.6875 - precision_9: 0.6786 - recall_9: 0.5707 - val_loss: 0.6209 - val_false_negatives_9: 242.0000 - val_false_positives_9: 175.0000 - val_true_negatives_9: 487.0000 - val_true_positives_9: 331.0000 - val_accuracy: 0.6623 - val_precision_9: 0.6542 - val_recall_9: 0.5777
# 10/10 [==============================] - 0s 17ms/step
# 10/10 [==============================] - 0s 19ms/step
# 10/10 [==============================] - 0s 18ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 10/10 [==============================] - 0s 5ms/step
# 10/10 [==============================] - 0s 5ms/step
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
#
# Data Computation Phase Completed Successfully.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.2s finished

# %%
# Saving the computed datasets. These are used in the analysis part of the tool
model_evaluation_df = model_evaluation_df.round(2)
raw_predictions_df = raw_predictions_df.round(2)
predictions_change_df = predictions_change_df.round(2)
volatility_df = volatility_df.round(2)
sensitivity_evaluation_df = sensitivity_evaluation_df.round(2)

model_evaluation_df.to_csv(
    f"{output_folder_location}/ml_models_evaluation.csv", index=False,
)
raw_predictions_df.to_csv(
    f"{output_folder_location}/sensitivity_predictions_raw.csv", index=False,
)
predictions_change_df.to_csv(
    f"{output_folder_location}/sensitivity_predictions_change.csv", index=False,
)
volatility_df.to_csv(
    f"{output_folder_location}/sensitivity_predictions_volatility.csv", index=False,
)
sensitivity_evaluation_df.to_csv(
    f"{output_folder_location}/sensitivity_output_evaluation.csv", index=False,
)

# %%
# The final step in the bias tool: creating visualization and textual explanations for the computed statistics

RunInteraction(first_dataset_csv_path, output, output_folder_location, verbose).main(recidivism_df)
# Out:
# Creating visualizations based on the computed datasets.
#
# Creating correlation plot.
#
# Creating delta bias plots.
#
# Creating sensitivity analysis plots.
#
# Visualization creation completed.

# %% [markdown]
# # 3. Bias Analysis using the Tool Output

# %% [markdown]
# We can analyze the output now that the tool has finished running. The data comes in several formats: raw csv files, useful for software pipelines or for detailed inspection, a set of visualizations, and textual Explanations through the logged outputs of the terminal. These will be outlined below, linking back to different concepts of bias.
#
# Although fairness might seem intuitive to grasp, there is no single definition of fairness.
# As we analyze the tool output, we will cover a range of fairness definitions and metrics that have been defined and employed within the context of ML. This list is not exhaustive: it is a selection of definitions that span a range of bias metrics, which have then adapted to be compatible with our tool.
# In addition, there are trade-offs between satisfying different kinds of fairness (e.g., Equal Opportunity, Demographic Parity, Counterfactual Fairness), making it hard to tackle issues relating to bias.
# As you complete the tutorial, you are welcome to use other ways of defining bias, including your own.

# %% [markdown]
# ### Quick Terminology
#
# In a binary classification problem, the user defines a positive class (e.g., output 1) and a negative class (e.g., output 0).
# If a prediction matches the outcome, it is known as a True Positive for positive predictions, and as a True Negative for negative predictions.
# Conversely, if a prediction does not match the outcome, it is known as a False Positive for positive predictions, and as a False Negative for negative predictions.
#
# We will abbreviate terminology in formulas as follows:
#
# TP = True Positives
#
# FP = False Positives
#
# TN = True Negatives
#
# FN = False Negatives
#
# It is useful to consider how well a classifier performs on each class, and whether it tends to *confuse* data from one class as belonging to a different one. A confusion matrix displays this data in a matrix format: each column corresponds to an original class (i.e. based on the labels known to be correct), while each row corresponds to a predicted class. Each quadrant represents a different prediction to actual output combination.
#
# Please run the below code snippet to visualize this:

# %%
def show_confusion_matrix(file=os.listdir("images/confusion_matrix/")):
    display(Image(f"images/confusion_matrix/{file}"))


interact(lambda x: show_confusion_matrix(x), x=[y for y in os.listdir("images/confusion_matrix/") if not y.startswith(".")])
# Out:
# interactive(children=(Dropdown(description='x', options=('ConfusionMatrixRedBlue.png',), value='ConfusionMatri…
# <function __main__.<lambda>(x)>

# %% [markdown]
# ## 3.1 CSV Files

# %% [markdown]
# Five CSV files are created during the analysis. These contain data on evaluation metrics and outputs along different groups.
#
# A **group** is defined as a subset of the main dataset that has been filtered down by a specific value of a feature. For example, taking the _race_ attribute, we can create 6 groups, based on the unique values of the feature (Other, African-American, Caucasian, Hispanic, Asian, Native American).

# %% [markdown]
# ### model_evaluation_df

# %% [markdown]
# This CSV evaluates the model performance, broken down across the (1) training type, (2) feature and (3) feature value. An example of this is: {training_type: original_dataset, feature: sex, feature_value: Male}.
#
# Various evaluation and bias metrics are provided in the computed columns, such as true_positives, accuracy, and equalized_odds.
#
# From this dataset we could draw conclusions about differences between groups, for example, say if the accuracy between sex–Male and sex–Female differed by a significant margin.

# %% [markdown]
# Please have a look at this dataset and the explanations provided below it.

# %%
model_evaluation_df
# Out:
#                       training_type  feature     feature_value  sample_count  \
# 0                  original_dataset      all               all          1235
# 1                  original_dataset     race             Other            67
# 2                  original_dataset     race  African-American           633
# 3                  original_dataset     race         Caucasian           439
# 4                  original_dataset     race          Hispanic            90
# ..                              ...      ...               ...           ...
# 104  remove_feature_c_charge_degree      sex              Male           995
# 105  remove_feature_c_charge_degree      sex            Female           240
# 106  remove_feature_c_charge_degree  age_cat   Greater than 45           244
# 107  remove_feature_c_charge_degree  age_cat           25 - 45           734
# 108  remove_feature_c_charge_degree  age_cat      Less than 25           257
#
#      true_positives  false_positives  true_negatives  false_negatives  \
# 0               353              172             481              229
# 1                 9                2              43               13
# 2               251              118             166               98
# 3                79               45             219               96
# 4                13                7              49               21
# ..              ...              ...             ...              ...
# 104             310              138             364              183
# 105              28               16             135               61
# 106              27               14             147               56
# 107             187               81             306              160
# 108             124               59              46               28
#
#      equalized_odds  equal_opportunity  statistical_parity  \
# 0          0.187287           0.285830            0.425101
# 1          0.048847           0.134328            0.164179
# 2          0.253604           0.396524            0.582938
# 3          0.130612           0.179954            0.282460
# 4          0.101111           0.144444            0.222222
# ..              ...                ...                 ...
# 104        0.191942           0.311558            0.450251
# 105        0.084848           0.116667            0.183333
# 106        0.075570           0.110656            0.168033
# 107        0.154002           0.254768            0.365123
# 108        0.311114           0.482490            0.712062
#
#      treatment_equality  accuracy  precision    recall        f1
# 0              0.117486  0.675304   0.672381  0.606529  0.637760
# 1              0.025000  0.776119   0.818182  0.409091  0.545455
# 2              0.161423  0.658768   0.680217  0.719198  0.699164
# 3              0.084112  0.678815   0.637097  0.451429  0.528428
# 4              0.063063  0.688889   0.650000  0.382353  0.481481
# ..                  ...       ...        ...       ...       ...
# 104            0.117148  0.677387   0.691964  0.628803  0.658874
# 105            0.053156  0.679167   0.636364  0.314607  0.421053
# 106            0.046667  0.713115   0.658537  0.325301  0.435484
# 107            0.090604  0.671662   0.697761  0.538905  0.608130
# 108            0.207018  0.661479   0.677596  0.815789  0.740299
#
# [109 rows x 16 columns]

# %% [markdown]
# Here is an explanation of each column:
#
# Grouping features: these features help identify a "group" of individuals in the dataset.
# - training_type: the type of modification that has been applied to the dataset: either using the original_dataset or a specific feature has been removed.
# - feature: the input feature that is being scrutinized (e.g., sex, race, age_cat)
# - feature_value: the specific value of the input feature that is being scrutinized (e.g., for sex, we have Male and Female)
# - sample_count: the number of individuals that have that specific feature value (e.g., the whole dataset has 1092 samples)
#
# Bias Metric Constructors: these four columns help define the bias metrics displayed in this CSV. They each display a ratio between 0 and 1. In a given row, summing the four metrics should yield a value of 1. The metrics are:
# - true_positives
# - false_positives
# - true_negatives
# - false_negatives
#
# Bias Metrics: using the bias metric constructors, five ways of defining bias emerge. These are all computed as a ratio between 0 and 1. For fairness to hold, the computed values for each metric should be the same (or as close as possible) between different groups. For example, we would say there is no bias in terms of equalized odds between sex-Male and sex-Female if both of them had the same value of 0.2. The larger the difference between groups, the larger the bias. The metrics are as follows:
# - **equalized_odds**: a harmonic mean of the odds of being correctly assigned a positive outcome (TP) and the odds of being incorrectly assigned a positive outcome (FP). For this to hold true, the value should be the same across all groups.
# - **equal_opportunity**: a relaxation of equalized_odds, where only the odds of being correctly assigned a positive outcome (TP) is computed. For this to hold true, the value should be the same across all groups.
# - **statistical_parity**: the positivity rate (i.e., TP + FP) of each group is computed, and should be the same across all groups for it to hold true.
# - **treatment_equality**: the ratio of false positives and false negatives should be the same for each group for this to hold true. The aim of this metric is to avoid a situation where some groups experience a higher ratio of false positives whilst other groups experience higher false negatives.
# - **Fairness in Relational Domains**: although not shown in the table, this definition is a relaxation of statistical parity. For it to hold true, the positivity rates between groups should be _similar_ to each other, with a user-defined cut-off. This definition may make more sense in practice, as it is unlikely that metrics will be exactly equal.
#
# Standard Evaluation Metrics: these are the classic ML metrics used to evaluate output performance.
# - accuracy: a ratio (beteween 0 and 1) of the proportion of correctly predicted instances.
# - precision: the proportion of positive identifications that were correct.
# - recall: the proportion of positives that were correctly identified.
# - f1: a harmonic mean of precision and recall, aiming to create a balance between the two metrics, as there is usually a trade-off between them.

# %% [markdown]
# ___
#
# Below are some interactive sliders and visualizations to help inspect the dataset further:

# %%
@interact
def show_filtered_model_evaluation_bias_metrics(
    column=[
        "equalized_odds",
        "equal_opportunity",
        "statistical_parity",
        "treatment_equality",
        "accuracy",
        "precision",
        "recall",
        "f1",
    ],
    x=(0, 1, 0.01),
):
    return model_evaluation_df.loc[model_evaluation_df[column] >= x]
# Out:
# interactive(children=(Dropdown(description='column', options=('equalized_odds', 'equal_opportunity', 'statisti…

# %%
@interact
def show_filtered_model_evaluation_sample_count(column=["sample_count"], x=(0, model_evaluation_df.sample_count.max(), 1)):
    return model_evaluation_df.loc[model_evaluation_df[column] >= x]
# Out:
# interactive(children=(Dropdown(description='column', options=('sample_count',), value='sample_count'), IntSlid…

# %% [markdown]
# You can also observe the data through a scatter plot (or other visualizations, should you wish to plot your own). Press "Run Interact" to start the plotting.

# %%
@interact_manual
def scatter_plot(
    x=list(model_evaluation_df.select_dtypes("number").columns),
    y=list(model_evaluation_df.select_dtypes("number").columns)[1:],
    theme=list(cf.themes.THEMES.keys()),
    colorscale=list(cf.colors._scales_names.keys()),
):

    model_evaluation_df.iplot(
        kind="scatter",
        x=x,
        y=y,
        mode="markers",
        xTitle=x.title(),
        yTitle=y.title(),
        title=f"Scatter Plot: {y.title()} vs {x.title()}",
        theme=theme,
        colorscale=colorscale,
    )
# Out:
# interactive(children=(Dropdown(description='x', options=('sample_count', 'true_positives', 'false_positives', …

# %% [markdown]
# **Exercise 4**: After playing around with the data, did you notice any difference in the performance of the Neural Network in relation to specific values of features? For example if there were big discrepancies in some evaluation metrics for different feature values of the same feature.

# %% [markdown]
# *Please single (or double) click this box and type your answer here.*

# %% [markdown]
# ### raw_predictions_df

# %% [markdown]
# This CSV is a log of all the predictions that the tool performs in the sensitivity analysis. **Sensitivity Analysis** is a type of analysis that involves changing a single input feature and observing any changes in output. This processes is repeated across all features and feature values, therefore obtaining an overall image of how sensitive the model is to slight changes in the input.
#
# Each row of this CSV represents a prediction for a given (1) training type, (2) feature, (3) original value and (4) new value. For example: {training_type: original_dataset, column_name: age, value_original: x, value_new: -6.0 from the original}. Please note that for continuous variables, the original value is perturbed at fixed percentages from the original value, x. For discrete variables, the original value is changed to each of the other unique values that the feature has.
#
# The output columns display the true label of the feature, the original predicted label, and the new predicted label based on changing the value of the feature. The standard deviation tells us how the probability of the output has changed, and the standard deviation direction tells us the direction it has changed in. For example, if a given sample had a 0.53 chance of being output 1, and a 0.47 chance of being output 0, the predicted label would be 1. After changing the value of one feature, the percentages may have changed to 0.55 and 0.45, respectively. This means that the predicted output has shifted 0.02 in the direction of 1.
#
# As it is raw data, this dataset can be quite large, but it may be useful to look at if wanting to inspect individuals samples (the file will be located under ``ml_bias_explainability/scripts/data/1_compass_recidivism/output/sensitivity_predictions_raw.csv``).

# %%
raw_predictions_df
# Out:
#                        training_type column_name    value_original  \
# 0                   original_dataset        race             Other
# 1                   original_dataset        race             Other
# 2                   original_dataset        race  African-American
# 3                   original_dataset        race         Caucasian
# 4                   original_dataset        race         Caucasian
# ...                              ...         ...               ...
# 1230  remove_feature_c_charge_degree     age_cat      Less than 25
# 1231  remove_feature_c_charge_degree     age_cat           25 - 45
# 1232  remove_feature_c_charge_degree     age_cat           25 - 45
# 1233  remove_feature_c_charge_degree     age_cat           25 - 45
# 1234  remove_feature_c_charge_degree     age_cat           25 - 45
#
#          value_new  label_predicted_original  label_predicted_new  \
# 0            Other                         0                    0
# 1            Other                         0                    0
# 2            Other                         0                    0
# 3            Other                         1                    1
# 4            Other                         0                    0
# ...            ...                       ...                  ...
# 1230  Less than 25                         1                    1
# 1231  Less than 25                         0                    0
# 1232  Less than 25                         1                    1
# 1233  Less than 25                         0                    0
# 1234  Less than 25                         0                    0
#
#       standard_deviation  standard_deviation_direction
# 0               0.000000                             1
# 1               0.000000                             1
# 2               0.028216                             0
# 3               0.002868                             0
# 4               0.004357                             0
# ...                  ...                           ...
# 1230            0.000000                             1
# 1231            0.056205                             1
# 1232            0.003826                             1
# 1233            0.079543                             1
# 1234            0.083421                             1
#
# [122265 rows x 8 columns]

# %% [markdown]
# **Bias Metrics present within Sensitivity Analysis**: there are four ways of defining bias that emerge.
# These metrics are similar to each other in that they want protected characteristics to not affect the output of a model. Given the similarity of the definitions, these are combined through the Sensitivity Analysis.
#
# - **Fairness Through Awareness**: any two individuals that are similar based on a computed similarity score should receive the same outcome. For the purpose of our tool, we consider two individuals as similar if they are equal for all input features, except for the one that is being changed.
# - **Test Fairness**: individuals from each sensitive group (e.g., Sex-Male and Sex-Female) must have an equal probability of correctly belonging to the positive class. In other words, given two almost identical individuals, which have the same values across all input features except for one or more sensitive attributes (e.g., one individual is Male and the other is Female), the probability of belonging to the positive output class must be equal for test fairness to hold.
# - **Counterfactual Fairness**: this is based on the notion that an outcome is fair for a particular individual if they would receive the same outcome given that they belonged to a different demographic group (in a Counterfactual World). Similarly to the other definitions, this metric is useful as it directly compares individuals that differ only through protected characteristics, to ensure that both sets of individuals receive the same predicted output.
# - **Conditional Statistical Parity**: this fairness definition states that all groups should have an equal probability of being assigned to a positive outcome given the same set of core input features (a user-defined set of features). This definition is similar to the others above, in that it also states that the output probabilities should not change simply by modifying non-core input features (e.g., the output should not change by modifying sensitive features such as Race).

# %% [markdown]
# ___
#
# You can use the function below to find filter specific combinations of input values:

# %%
def raw_predictions_interact(
    training_type,
    column_name,
    label_predicted_original,
    label_predicted_new,
):
    return raw_predictions_df[
        (raw_predictions_df["training_type"] == training_type)
        & (raw_predictions_df["column_name"] == column_name)
        & (raw_predictions_df["label_predicted_original"] == label_predicted_original)
        & (raw_predictions_df["label_predicted_new"] == label_predicted_new)
    ]


interact(
    raw_predictions_interact,
    training_type=list(set(raw_predictions_df["training_type"].values)),
    column_name=list(set(raw_predictions_df["column_name"].values)),
    label_predicted_original=[1, 0],
    label_predicted_new=[1, 0],
)
# Out:
# interactive(children=(Dropdown(description='training_type', options=('remove_feature_c_charge_degree', 'remove…
# <function __main__.raw_predictions_interact(training_type, column_name, label_predicted_original, label_predicted_new)>

# %% [markdown]
# You can also observe the data through a bar plot (or other visualizations, should you wish to plot your own, but please be aware that this dataset is very large).
#
# To read this chart: if the label_predicted_new matches the label_predicted_original, it means that the sensitivity analysis had no effect on the output. Otherwise, the predicted output has changed.

# %%
ax = raw_predictions_df.groupby(['label_predicted_original','label_predicted_new'])['label_predicted_original'].count().unstack(0).plot.bar(figsize=(14,8))
_ = ax.set_xlabel('label_predicted_new')
_ = ax.set_ylabel('Frequency')
ax.figure

# %% [markdown]
# ### predictions_change_df

# %% [markdown]
# This CSV is an aggregate of the raw_predictions_df. It introduces a size column, that tells the practitioner the effect of perturbing the value of the raw samples on the predicted output label. For example: {training_type: original_dataset, column_name: age, value_original: x, value_new: -3.0 from the original} has some samples where the predicted output changes, and some samples where it stays the same. Rows of interest might be those where a significant number of predictions change. For example, when it comes to bias and discrimination, a problematic outcome might be a significant proportion of predictions changing simply by modifying sex from Male to Female.

# %% [markdown]
# Please have a quick play with this dataset. Again, interactive displays have been included to help draw conclusions

# %%
predictions_change_df
# Out:
#                       training_type column_name value_original  \
# 0                  original_dataset     age_cat        25 - 45
# 1                  original_dataset     age_cat        25 - 45
# 2                  original_dataset     age_cat        25 - 45
# 3                  original_dataset     age_cat        25 - 45
# 4                  original_dataset     age_cat        25 - 45
# ..                              ...         ...            ...
# 116  remove_feature_c_charge_degree         sex           Male
# 117  remove_feature_c_charge_degree         sex           Male
# 118  remove_feature_c_charge_degree         sex           Male
# 119  remove_feature_c_charge_degree         sex           Male
# 120  remove_feature_c_charge_degree         sex           Male
#
#            value_new  label_predicted_original  label_predicted_new  size
# 0            25 - 45                         0                    0   444
# 1            25 - 45                         1                    1   290
# 2    Greater than 45                         0                    0   444
# 3    Greater than 45                         1                    1   290
# 4       Less than 25                         0                    0   363
# ..               ...                       ...                  ...   ...
# 116           Female                         0                    0   547
# 117           Female                         1                    0   137
# 118           Female                         1                    1   311
# 119             Male                         0                    0   547
# 120             Male                         1                    1   448
#
# [1080 rows x 7 columns]

# %%
def aggregate_predictions_interact(training_type, column_name):
    return predictions_change_df[
        (predictions_change_df["training_type"] == training_type)
        & (predictions_change_df["column_name"] == column_name)
    ]


interact(
    aggregate_predictions_interact,
    training_type=list(set(predictions_change_df["training_type"].values)),
    column_name=list(set(predictions_change_df["column_name"].values)),
)
# Out:
# interactive(children=(Dropdown(description='training_type', options=('remove_feature_c_charge_degree', 'remove…
# <function __main__.aggregate_predictions_interact(training_type, column_name)>

# %% [markdown]
# **Exercise 5**: After playing around with the data, can you share an example where in the original dataset training type, changing a feature value led to many predictions changing? For that same feature change combination, was there another training type that led to fewer changes in the prediction? The idea here is to mitigate the number of samples changing for features at risk of being discriminatory (_Fairness Through Awareness_ definition of bias).

# %% [markdown]
# *Please single (or double) click this box and type your answer here.*

# %% [markdown]
# You can also observe the data through a bar plot (or other visualizations, should you wish to plot your own).
#
# The chart below is a way of viewing if the sensitivity analysis had an effect on the output (true if predicted output changed, false otherwise). It is currently broken down by training type, but you can have a play with it and change what column is being used.

# %%
predictions_change_visual_df = predictions_change_df.copy()
predictions_change_visual_df["prediction_change"] = predictions_change_visual_df.label_predicted_original != predictions_change_visual_df.label_predicted_new
ax = predictions_change_visual_df.groupby([
                    "training_type", # try changing this with the feature "column_name", or another feature of your choice                   
                    "prediction_change",
                ])["size"].sum().unstack(0).plot.bar(figsize=(14,8))
_ = ax.set_ylabel('frequency')
ax.figure

# %% [markdown]
# ## 3.2 Visualizations

# %% [markdown]
# This section covers the visualizations that the tool outputs. The visualizations are designed to help inform a practitioner on what kinds of biases might be present in their dataset, and also what the effect is of removing each feature present in the dataset, should the practitioner wish to remove features.
# It is important to note that there is a trade-off between these different kinds of fairness and also with model performance. Therefore, a practitioner may want to use the visualizations to observe the effect of satisfying different kinds of fairness, whilst taking model performance into account.

# %% [markdown]
# ### Analysis 1: Feature Evaluation – Correlation Plot

# %% [markdown]
# This visualization is a Pearson’s Correlation for each feature combination of the features in the original dataset. The scale is 0 to 1 (absolute values), where 0 is uncorrelated and 1 is fully correlated. Below you'll be able to see a correlation plot for the features in the dataset: to aid inspection, only values above a threshold of 0.2 are displayed. This visualization is useful for practitioners to observe correlations between features. It might be useful in uncovering features that are proxies for biased features, in order to remove them from the model. This brings us to our final bias definition:

# %% [markdown]
# **Fairness through Unawareness**:
# In this definition, a model can be considered fair as long as it does not use any input features that are deemed to be protected characteristics (e.g. Race, Sex). This simply involves the practitioner removing discriminatory features from the dataset before the model is even trained.
# This is quite popular in practice, as it is quick and straightforward to implement, without needing to compute metrics to evaluate potential biases. For example, Google has removed gender labels from image recognition models, replacing labels referring to _man_ and _woman_ with _person_, with the aim of reducing bias.
# However, the practitioner may want to take this one step further and also remove closely correlated _proxy_ features, as those features may end up being used by the model as an approximation of the removed sensitive features.

# %%
analysis_1_compass = f"{output_folder_location}/visualizations/analysis_1"

def show_analysis_1(file=os.listdir(analysis_1_compass)):
    display(Image(f"{analysis_1_compass}/{file}"))

interact(
    lambda x: show_analysis_1(x),
    x=[y for y in os.listdir(analysis_1_compass) if not y.startswith(".")],
)
# Out:
# interactive(children=(Dropdown(description='x', options=('correlation_plot.png',), value='correlation_plot.png…
# <function __main__.<lambda>(x)>

# %% [markdown]
# **Exercise 6**: Which feature pairs have the highest correlation between them? Given the _Fairness through Unawareness_ definition of bias, would you keep both, one, or neither feature?

# %% [markdown]
# *Please single (or double) click this box and type your answer here.*

# %% [markdown]
# ### Analysis 2: Relative Delta Bias

# %% [markdown]
# These visualizations compare the differences in feature value metrics for each feature by training type, computing a feature value delta using the max difference in each of the summary metrics.
#
# In other words:
# - For each performance metric (e.g., accuracy, recall)
# - For each training type (e.g., all_features, remove_sex)
# - For each user-chosen feature that has computed metrics (e.g., a user may choose protected characteristics such as Race and Sex)
# - A delta is computed between the maximum and minimum performance of feature values of a feature (i.e., a group).

# %% [markdown]
# Linking back to the bias definitions in the section introducing model_evaluation_df, in a truly fair World, metrics such as _equalized_odds_ should be equal among all groups for a given feature. I.e., the _equalized_odds_delta_ should be 0, as that implies that all groups have the same value.
#
# A practitioner will want to use this data to select a training type that leads to the lowest relative delta values for a given performance or bias metric. In practice, it may be hard to find an optimal training type that is the minimum delta for all metrics.

# %% [markdown]
# The sketches below are grouped by feature, and have two display modes: stacked or small multiples. Double clicking on visualizations will make it zoom in, which might make the graph more readable.

# %%
analysis_2_compass = f"{output_folder_location}/visualizations/analysis_2_and_3_ml_models/analysis_2_relative_delta_bias/"

def show_analysis_2(file=os.listdir(analysis_2_compass)):
    display(Image(f"{analysis_2_compass}/{file}"))

interact(
    lambda x: show_analysis_2(x),
    x=[y for y in os.listdir(analysis_2_compass) if not y.startswith(".")],
)
# Out:
# interactive(children=(Dropdown(description='x', options=('age_cat_small_multiples.png', 'all_stacked_visualiza…
# <function __main__.<lambda>(x)>

# %% [markdown]
# **Exercise 7**: For variable statistical_party_delta, and feature sex, which training type results in the lowest delta metric? Is this an improvement over the original dataset training type? For the definition of statistical_parity_delta, is this dataset now fair?

# %% [markdown]
# *Please single (or double) click this box and type your answer here.*

# %% [markdown]
# **Exercise 8**: The 4 bias metrics displayed here are equalized odds, equal opportunity, statistical parity and treatment equality. Out of these bias types, are there any that you are likely to use for this kind of dataset? How did you decide which to use?

# %% [markdown]
# *Please single (or double) click this box and type your answer here.*

# %% [markdown]
# ### Analysis 3: Absolute Delta Bias

# %% [markdown]
# This visualization looks at the effect of training type on the same feature value for each evaluation metric. The least biased training option for a feature value can be considered the one with the highest values in the performance metrics.
#
# Whilst Analysis 2 looks at the between-feature value effects of different training methods, aiming to minimize the discrepancies in metrics between feature values, Analysis 3 looks at the within-feature value effects of different training types, when compared to the original dataset. In other words, this analysis tells a practitioner if performing a certain modification on the original dataset leads to an improvement in metrics: a positive delta suggests an improvement, whilst a negative value means that the new training method is worse than the original one.

# %%
analysis_3_compass = f"{output_folder_location}/visualizations/analysis_2_and_3_ml_models/analysis_3_absolute_delta_bias"

def show_analysis_3(file=os.listdir(analysis_3_compass)):
    display(Image(f"{analysis_3_compass}/{file}"))

interact(
    lambda x: show_analysis_3(x),
    x=[y for y in os.listdir(analysis_3_compass) if not y.startswith(".")],
)
# Out:
# interactive(children=(Dropdown(description='x', options=('race_african_american_small_multiples.png', 'race_ot…
# <function __main__.<lambda>(x)>

# %% [markdown]
# **Exercise 9**: For variable equalized_odds_delta, and feature value African American (race), which training type results in the biggest improvement in score? If you chose this training type, how does it affect the equalized_odds_delta of feature value Caucasian (race)?

# %% [markdown]
# *Please single (or double) click this box and type your answer here.*

# %% [markdown]
# ### Analysis 4: Prediction Change

# %% [markdown]
# These visualizations look at the effect of training type on the ratio of samples changing output, for a given sensitive feature and feature value. Based on the bias definitions introduced in raw_predictions_df, the least biased training option for a feature value can be considered the one with the lowest number of samples changing output when that feature value is modified.
#
# In the visualization, any training methods with a lower ratio than the original (all_features) signifies an improvement in bias prevention, whilst a higher ratio signifies that the original training method is better.

# %%
analysis_4_compass = f"{output_folder_location}/visualizations/analysis_4_and_5_sensitivity/analysis_4_prediction_change"

def show_analysis_4(file=os.listdir(analysis_4_compass)):
    display(Image(f"{analysis_4_compass}/{file}"))
    
interact(
    lambda x: show_analysis_4(x),
    x=[y for y in os.listdir(analysis_4_compass) if not y.startswith(".")],
)
# Out:
# interactive(children=(Dropdown(description='x', options=('race_other_stacked_visualization.png', 'age_x_stacke…
# <function __main__.<lambda>(x)>

# %% [markdown]
# **Exercise 10**: Pick a feature value, and write down which training type leads to the lowest ratio of prediction changes, and which leads to the highest ratio.

# %% [markdown]
# *Please single (or double) click this box and type your answer here.*

# %% [markdown]
# ### Analysis 5: Prediction Volatility

# %% [markdown]
# These visualizations are very similar to those shown in Analysis 4, however, instead of looking at prediction changes, they look at changes in the prediction probabilities. The least biased training option for a feature value can be considered the one with the lowest changes in the size of probability outputs when that feature value is modified.

# %%
analysis_5_compass = f"{output_folder_location}/visualizations/analysis_4_and_5_sensitivity/analysis_5_prediction_volatility"

def show_analysis_5(file=os.listdir(analysis_5_compass)):
    display(Image(f"{analysis_5_compass}/{file}"))

interact(
    lambda x: show_analysis_5(x),
    x=[y for y in os.listdir(analysis_5_compass) if not y.startswith(".")],
)
# Out:
# interactive(children=(Dropdown(description='x', options=('race_other_stacked_visualization.png', 'age_x_stacke…
# <function __main__.<lambda>(x)>

# %% [markdown]
# **Exercise 11**: Looking at the same feature value that you picked in Exercise 10, has the training type that led to the lowest ratio of prediction changes, and the one that led to the highest ratio changed? If so, what are they now?

# %% [markdown]
# *Please single (or double) click this box and type your answer here.*

# %% [markdown]
# ___
# ### End of the main part of the study
# You have now completed the main part of the study. There is an optional exercise below that invites you to apply concepts of bias to a new dataset, should you wish to spend more time learning about bias.
#
# If you decide to end the study here, please make sure to **manually save the Notebook** (if you click on _file_ in the top left of the menu bar, there is an option to _save_), and share it with the researchers (also in _file_, click _download_ and select the _.ipynb_ format. You will then be invited to take part in a follow-up interview.
#
# ___

# %% [markdown]
# # 4. OPTIONAL Exploration Exercise with a new Dataset

# %% [markdown]
# The previous sections introduced you to concepts of bias through a tool developed for this study. It followed a dataset called COMPAS Recidivism Dataset. The following **optional** section is meant to be exploratory: it is meant to get you to think about bias in ML.
#
# **Exercise 12**: Please try the tool yourself on the following dataset: german credit. This is a popular dataset used for research within the Bias community. Boilerplate code is provided below to help compute the analysis. You are also free to try it on a dataset of your choice, should you prefer to do so.
#
# - Please run the analysis and observe the results.
# - Feel free to implement your own additional code based on other parts of the tutorial or your own knowledge, e.g., to help with visualizing the data, or with understanding bias, or to improve the ML model by trying other parameters. Feel free to add more code boxes using the + button at the top menu of the Notebook.
# - Please write down a few (at least 3) interesting insights that would help you in model building (e.g., switching training type to remove feature x results in a lower bias for feature y). Feel free to write answers in the space provided _below_.
# - Think about the different bias metrics (introduced in this tutorial or from your own research or knowledge). Which would you use and why?
#
# When you are done exploring, please save the Notebook and share it with the researchers. You will then be invited to take part in a follow-up interview.

# %% [markdown]
# Run the code below to compile the analysis. This is the skeleton code intended to get the tool to compute the analysis, but feel free to add additional code

# %%
# Variables refering to folder locations for the German Credit dataset are defined here
"""
Provide the path to the dataset
"""
german_dataset_csv_path = "scripts/data/3_german_credit/german_credit_data.csv"

"""
Provide a list of columns that need to be removed from the dataset in the pre-processing stage
"""
german_dataset_columns_to_remove = Helper.read_yaml("scripts/data/3_german_credit/columns_to_remove.yml")

"""
The desired location of the analysis output. These can be accessed at a later stage, 
to avoid having to re-run everything.
"""
german_output_folder_location = "scripts/data/3_german_credit/output"

# %%
# Load and clean the dataset
def clean_dataset(csv_path, columns_to_remove):
    # The dataset used is taken from https://archive.ics.uci.edu/ml/datasets/statlog+(german+credit+data)
    df = pd.read_csv(csv_path, index_col=0)

    # get rid of columns that shouldn't be in the input model
    filtered_columns_to_remove = df.filter(columns_to_remove)
    df.drop(filtered_columns_to_remove, inplace=True, axis=1)

    # lowercase + underscore for columns
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.replace(" ", "_")

    # map output to integer values
    df["risk"].replace({"bad": 0, "good": 1}, inplace=True)

    # Ensure validity of inputs – No NaNs
    object_list, numeric_list = Helper.get_df_types_list(df)
    for column in object_list:
        df[column].fillna("", inplace=True)
    for column in numeric_list:
        df[column].fillna(-1, inplace=True)

    return df

german_credit_df = clean_dataset(german_dataset_csv_path, german_dataset_columns_to_remove)
german_credit_df
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0     67    male    2     own                           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little                            2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little                            1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little                             804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
#      duration              purpose  risk
# 0           6             radio/TV     1
# 1          48             radio/TV     0
# 2          12            education     1
# 3          42  furniture/equipment     1
# 4          24                  car     0
# ..        ...                  ...   ...
# 995        12  furniture/equipment     1
# 996        30                  car     1
# 997        12             radio/TV     1
# 998        45             radio/TV     0
# 999        45                  car     1
#
# [1000 rows x 10 columns]

# %% [markdown]
# Here is a brief explanation of each feature:
# - age: ranges from 19 to 75
# - sex: male or female
# - job: 0 - unskilled and non-resident, 1 - unskilled and resident, 2 - skilled, 3 - highly skilled
# - housing: own, rent, or free
# - savings_accounts: amount of money in the account: unknown (empty entry), little, moderate, quite rich, rich
# - checking_account: amount of money in the account: unknown (empty entry), little, moderate, quite rich, rich
# - credit_amount: between 250 and 18424 Deutsch Mark (DM)
# - duration: how long the loan is taken out for. Ranges between 4 and 72 months
# - purpose: car, furniture/equipment, radio/TV, domestic appliances, repairs, education, business, vacation/others
# - risk (output feature): good or bad credit risks. 1 is good credit risk, 0 is bad credit risk.

# %%
# Define the following parameters for the tool
german_training_types = [
        "original_dataset",
        "remove_feature",
    ]
german_features_of_interest = ["age", "sex"]
german_output = "risk"
german_unique_values = 10
german_verbose = False

# %%
# Parameters for the trained Neural Network model. You can optionally modify them if you choose to, but it is not necessary.
german_best_params = dict(
    batch_size=256,
    epochs=15,
    optimizer="Adam",
    init_mode="he_uniform",
    activation="relu",
    weight_constraint=3,
    dropout_rate=0.1,
    neurons=64,
    hidden_layers=2,
)

# %%
# Running the analysis itself
(
    german_model_evaluation_df,
    german_raw_predictions_df,
    german_predictions_change_df,
    german_volatility_df,
    german_sensitivity_evaluation_df,
) = CompileModelAndAnalysis(
    german_training_types,
    german_features_of_interest,
    german_output,
    german_dataset_columns_to_remove,
    german_dataset_csv_path,
    None,
    german_unique_values,
    german_best_params,
).main(
    german_credit_df
)
# Out:
# RUNNING ANALYSIS FOR TRAINING TYPE: 'original_dataset'
#
# List of numeric features for this dataset: ['age', 'job', 'credit_amount', 'duration']
# List of non-numeric features: ['sex', 'housing', 'saving_accounts', 'checking_account', 'purpose']
#
# Training the model:
# Epoch 1/15
# 3/3 [==============================] - 2s 404ms/step - loss: 0.8183 - false_negatives_10: 281.0000 - false_positives_10: 49.0000 - true_negatives_10: 131.0000 - true_positives_10: 139.0000 - accuracy: 0.4500 - precision_10: 0.7394 - recall_10: 0.3310 - val_loss: 0.7104 - val_false_negatives_10: 63.0000 - val_false_positives_10: 26.0000 - val_true_negatives_10: 35.0000 - val_true_positives_10: 76.0000 - val_accuracy: 0.5550 - val_precision_10: 0.7451 - val_recall_10: 0.5468
# Epoch 2/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.7263 - false_negatives_10: 201.0000 - false_positives_10: 90.0000 - true_negatives_10: 90.0000 - true_positives_10: 219.0000 - accuracy: 0.5150 - precision_10: 0.7087 - recall_10: 0.5214 - val_loss: 0.6484 - val_false_negatives_10: 38.0000 - val_false_positives_10: 42.0000 - val_true_negatives_10: 19.0000 - val_true_positives_10: 101.0000 - val_accuracy: 0.6000 - val_precision_10: 0.7063 - val_recall_10: 0.7266
# Epoch 3/15
# 3/3 [==============================] - 0s 56ms/step - loss: 0.6646 - false_negatives_10: 131.0000 - false_positives_10: 130.0000 - true_negatives_10: 50.0000 - true_positives_10: 289.0000 - accuracy: 0.5650 - precision_10: 0.6897 - recall_10: 0.6881 - val_loss: 0.6139 - val_false_negatives_10: 19.0000 - val_false_positives_10: 47.0000 - val_true_negatives_10: 14.0000 - val_true_positives_10: 120.0000 - val_accuracy: 0.6700 - val_precision_10: 0.7186 - val_recall_10: 0.8633
# Epoch 4/15
# 3/3 [==============================] - 0s 59ms/step - loss: 0.6238 - false_negatives_10: 53.0000 - false_positives_10: 147.0000 - true_negatives_10: 33.0000 - true_positives_10: 367.0000 - accuracy: 0.6667 - precision_10: 0.7140 - recall_10: 0.8738 - val_loss: 0.5956 - val_false_negatives_10: 3.0000 - val_false_positives_10: 53.0000 - val_true_negatives_10: 8.0000 - val_true_positives_10: 136.0000 - val_accuracy: 0.7200 - val_precision_10: 0.7196 - val_recall_10: 0.9784
# Epoch 5/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.6031 - false_negatives_10: 22.0000 - false_positives_10: 156.0000 - true_negatives_10: 24.0000 - true_positives_10: 398.0000 - accuracy: 0.7033 - precision_10: 0.7184 - recall_10: 0.9476 - val_loss: 0.5855 - val_false_negatives_10: 0.0000e+00 - val_false_positives_10: 56.0000 - val_true_negatives_10: 5.0000 - val_true_positives_10: 139.0000 - val_accuracy: 0.7200 - val_precision_10: 0.7128 - val_recall_10: 1.0000
# Epoch 6/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.5789 - false_negatives_10: 15.0000 - false_positives_10: 155.0000 - true_negatives_10: 25.0000 - true_positives_10: 405.0000 - accuracy: 0.7167 - precision_10: 0.7232 - recall_10: 0.9643 - val_loss: 0.5782 - val_false_negatives_10: 1.0000 - val_false_positives_10: 53.0000 - val_true_negatives_10: 8.0000 - val_true_positives_10: 138.0000 - val_accuracy: 0.7300 - val_precision_10: 0.7225 - val_recall_10: 0.9928
# Epoch 7/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.5712 - false_negatives_10: 12.0000 - false_positives_10: 154.0000 - true_negatives_10: 26.0000 - true_positives_10: 408.0000 - accuracy: 0.7233 - precision_10: 0.7260 - recall_10: 0.9714 - val_loss: 0.5715 - val_false_negatives_10: 4.0000 - val_false_positives_10: 51.0000 - val_true_negatives_10: 10.0000 - val_true_positives_10: 135.0000 - val_accuracy: 0.7250 - val_precision_10: 0.7258 - val_recall_10: 0.9712
# Epoch 8/15
# 3/3 [==============================] - 0s 55ms/step - loss: 0.5632 - false_negatives_10: 14.0000 - false_positives_10: 150.0000 - true_negatives_10: 30.0000 - true_positives_10: 406.0000 - accuracy: 0.7267 - precision_10: 0.7302 - recall_10: 0.9667 - val_loss: 0.5648 - val_false_negatives_10: 4.0000 - val_false_positives_10: 49.0000 - val_true_negatives_10: 12.0000 - val_true_positives_10: 135.0000 - val_accuracy: 0.7350 - val_precision_10: 0.7337 - val_recall_10: 0.9712
# Epoch 9/15
# 3/3 [==============================] - 0s 55ms/step - loss: 0.5608 - false_negatives_10: 22.0000 - false_positives_10: 140.0000 - true_negatives_10: 40.0000 - true_positives_10: 398.0000 - accuracy: 0.7300 - precision_10: 0.7398 - recall_10: 0.9476 - val_loss: 0.5583 - val_false_negatives_10: 4.0000 - val_false_positives_10: 49.0000 - val_true_negatives_10: 12.0000 - val_true_positives_10: 135.0000 - val_accuracy: 0.7350 - val_precision_10: 0.7337 - val_recall_10: 0.9712
# Epoch 10/15
# 3/3 [==============================] - 0s 54ms/step - loss: 0.5487 - false_negatives_10: 27.0000 - false_positives_10: 131.0000 - true_negatives_10: 49.0000 - true_positives_10: 393.0000 - accuracy: 0.7367 - precision_10: 0.7500 - recall_10: 0.9357 - val_loss: 0.5520 - val_false_negatives_10: 5.0000 - val_false_positives_10: 48.0000 - val_true_negatives_10: 13.0000 - val_true_positives_10: 134.0000 - val_accuracy: 0.7350 - val_precision_10: 0.7363 - val_recall_10: 0.9640
# Epoch 11/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5464 - false_negatives_10: 27.0000 - false_positives_10: 130.0000 - true_negatives_10: 50.0000 - true_positives_10: 393.0000 - accuracy: 0.7383 - precision_10: 0.7514 - recall_10: 0.9357 - val_loss: 0.5461 - val_false_negatives_10: 5.0000 - val_false_positives_10: 47.0000 - val_true_negatives_10: 14.0000 - val_true_positives_10: 134.0000 - val_accuracy: 0.7400 - val_precision_10: 0.7403 - val_recall_10: 0.9640
# Epoch 12/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5349 - false_negatives_10: 27.0000 - false_positives_10: 128.0000 - true_negatives_10: 52.0000 - true_positives_10: 393.0000 - accuracy: 0.7417 - precision_10: 0.7543 - recall_10: 0.9357 - val_loss: 0.5404 - val_false_negatives_10: 6.0000 - val_false_positives_10: 45.0000 - val_true_negatives_10: 16.0000 - val_true_positives_10: 133.0000 - val_accuracy: 0.7450 - val_precision_10: 0.7472 - val_recall_10: 0.9568
# Epoch 13/15
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5297 - false_negatives_10: 30.0000 - false_positives_10: 126.0000 - true_negatives_10: 54.0000 - true_positives_10: 390.0000 - accuracy: 0.7400 - precision_10: 0.7558 - recall_10: 0.9286 - val_loss: 0.5349 - val_false_negatives_10: 7.0000 - val_false_positives_10: 45.0000 - val_true_negatives_10: 16.0000 - val_true_positives_10: 132.0000 - val_accuracy: 0.7400 - val_precision_10: 0.7458 - val_recall_10: 0.9496
# Epoch 14/15
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5305 - false_negatives_10: 29.0000 - false_positives_10: 126.0000 - true_negatives_10: 54.0000 - true_positives_10: 391.0000 - accuracy: 0.7417 - precision_10: 0.7563 - recall_10: 0.9310 - val_loss: 0.5297 - val_false_negatives_10: 7.0000 - val_false_positives_10: 45.0000 - val_true_negatives_10: 16.0000 - val_true_positives_10: 132.0000 - val_accuracy: 0.7400 - val_precision_10: 0.7458 - val_recall_10: 0.9496
# Epoch 15/15
# 3/3 [==============================] - 0s 61ms/step - loss: 0.5234 - false_negatives_10: 34.0000 - false_positives_10: 126.0000 - true_negatives_10: 54.0000 - true_positives_10: 386.0000 - accuracy: 0.7333 - precision_10: 0.7539 - recall_10: 0.9190 - val_loss: 0.5249 - val_false_negatives_10: 7.0000 - val_false_positives_10: 45.0000 - val_true_negatives_10: 16.0000 - val_true_positives_10: 132.0000 - val_accuracy: 0.7400 - val_precision_10: 0.7458 - val_recall_10: 0.9496
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 64ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 5ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 4ms/step
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_age'
#
# List of numeric features for this dataset: ['job', 'credit_amount', 'duration']
# List of non-numeric features: ['sex', 'housing', 'saving_accounts', 'checking_account', 'purpose']
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.8s finished
# Training the model:
# Epoch 1/15
# 3/3 [==============================] - 2s 384ms/step - loss: 0.6687 - false_negatives_11: 45.0000 - false_positives_11: 169.0000 - true_negatives_11: 11.0000 - true_positives_11: 375.0000 - accuracy: 0.6433 - precision_11: 0.6893 - recall_11: 0.8929 - val_loss: 0.6292 - val_false_negatives_11: 5.0000 - val_false_positives_11: 57.0000 - val_true_negatives_11: 4.0000 - val_true_positives_11: 134.0000 - val_accuracy: 0.6900 - val_precision_11: 0.7016 - val_recall_11: 0.9640
# Epoch 2/15
# 3/3 [==============================] - 0s 54ms/step - loss: 0.6394 - false_negatives_11: 23.0000 - false_positives_11: 172.0000 - true_negatives_11: 8.0000 - true_positives_11: 397.0000 - accuracy: 0.6750 - precision_11: 0.6977 - recall_11: 0.9452 - val_loss: 0.6007 - val_false_negatives_11: 3.0000 - val_false_positives_11: 57.0000 - val_true_negatives_11: 4.0000 - val_true_positives_11: 136.0000 - val_accuracy: 0.7000 - val_precision_11: 0.7047 - val_recall_11: 0.9784
# Epoch 3/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.6106 - false_negatives_11: 18.0000 - false_positives_11: 170.0000 - true_negatives_11: 10.0000 - true_positives_11: 402.0000 - accuracy: 0.6867 - precision_11: 0.7028 - recall_11: 0.9571 - val_loss: 0.5777 - val_false_negatives_11: 4.0000 - val_false_positives_11: 55.0000 - val_true_negatives_11: 6.0000 - val_true_positives_11: 135.0000 - val_accuracy: 0.7050 - val_precision_11: 0.7105 - val_recall_11: 0.9712
# Epoch 4/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5881 - false_negatives_11: 19.0000 - false_positives_11: 163.0000 - true_negatives_11: 17.0000 - true_positives_11: 401.0000 - accuracy: 0.6967 - precision_11: 0.7110 - recall_11: 0.9548 - val_loss: 0.5598 - val_false_negatives_11: 3.0000 - val_false_positives_11: 54.0000 - val_true_negatives_11: 7.0000 - val_true_positives_11: 136.0000 - val_accuracy: 0.7150 - val_precision_11: 0.7158 - val_recall_11: 0.9784
# Epoch 5/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.5713 - false_negatives_11: 14.0000 - false_positives_11: 157.0000 - true_negatives_11: 23.0000 - true_positives_11: 406.0000 - accuracy: 0.7150 - precision_11: 0.7211 - recall_11: 0.9667 - val_loss: 0.5454 - val_false_negatives_11: 3.0000 - val_false_positives_11: 51.0000 - val_true_negatives_11: 10.0000 - val_true_positives_11: 136.0000 - val_accuracy: 0.7300 - val_precision_11: 0.7273 - val_recall_11: 0.9784
# Epoch 6/15
# 3/3 [==============================] - 0s 54ms/step - loss: 0.5626 - false_negatives_11: 20.0000 - false_positives_11: 150.0000 - true_negatives_11: 30.0000 - true_positives_11: 400.0000 - accuracy: 0.7167 - precision_11: 0.7273 - recall_11: 0.9524 - val_loss: 0.5340 - val_false_negatives_11: 5.0000 - val_false_positives_11: 49.0000 - val_true_negatives_11: 12.0000 - val_true_positives_11: 134.0000 - val_accuracy: 0.7300 - val_precision_11: 0.7322 - val_recall_11: 0.9640
# Epoch 7/15
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5519 - false_negatives_11: 23.0000 - false_positives_11: 146.0000 - true_negatives_11: 34.0000 - true_positives_11: 397.0000 - accuracy: 0.7183 - precision_11: 0.7311 - recall_11: 0.9452 - val_loss: 0.5255 - val_false_negatives_11: 5.0000 - val_false_positives_11: 47.0000 - val_true_negatives_11: 14.0000 - val_true_positives_11: 134.0000 - val_accuracy: 0.7400 - val_precision_11: 0.7403 - val_recall_11: 0.9640
# Epoch 8/15
# 3/3 [==============================] - 0s 232ms/step - loss: 0.5342 - false_negatives_11: 21.0000 - false_positives_11: 140.0000 - true_negatives_11: 40.0000 - true_positives_11: 399.0000 - accuracy: 0.7317 - precision_11: 0.7403 - recall_11: 0.9500 - val_loss: 0.5189 - val_false_negatives_11: 6.0000 - val_false_positives_11: 46.0000 - val_true_negatives_11: 15.0000 - val_true_positives_11: 133.0000 - val_accuracy: 0.7400 - val_precision_11: 0.7430 - val_recall_11: 0.9568
# Epoch 9/15
# 3/3 [==============================] - 0s 58ms/step - loss: 0.5241 - false_negatives_11: 23.0000 - false_positives_11: 138.0000 - true_negatives_11: 42.0000 - true_positives_11: 397.0000 - accuracy: 0.7317 - precision_11: 0.7421 - recall_11: 0.9452 - val_loss: 0.5137 - val_false_negatives_11: 7.0000 - val_false_positives_11: 46.0000 - val_true_negatives_11: 15.0000 - val_true_positives_11: 132.0000 - val_accuracy: 0.7350 - val_precision_11: 0.7416 - val_recall_11: 0.9496
# Epoch 10/15
# 3/3 [==============================] - 0s 55ms/step - loss: 0.5299 - false_negatives_11: 24.0000 - false_positives_11: 131.0000 - true_negatives_11: 49.0000 - true_positives_11: 396.0000 - accuracy: 0.7417 - precision_11: 0.7514 - recall_11: 0.9429 - val_loss: 0.5102 - val_false_negatives_11: 7.0000 - val_false_positives_11: 45.0000 - val_true_negatives_11: 16.0000 - val_true_positives_11: 132.0000 - val_accuracy: 0.7400 - val_precision_11: 0.7458 - val_recall_11: 0.9496
# Epoch 11/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.5214 - false_negatives_11: 29.0000 - false_positives_11: 121.0000 - true_negatives_11: 59.0000 - true_positives_11: 391.0000 - accuracy: 0.7500 - precision_11: 0.7637 - recall_11: 0.9310 - val_loss: 0.5077 - val_false_negatives_11: 8.0000 - val_false_positives_11: 44.0000 - val_true_negatives_11: 17.0000 - val_true_positives_11: 131.0000 - val_accuracy: 0.7400 - val_precision_11: 0.7486 - val_recall_11: 0.9424
# Epoch 12/15
# 3/3 [==============================] - 0s 54ms/step - loss: 0.5152 - false_negatives_11: 29.0000 - false_positives_11: 122.0000 - true_negatives_11: 58.0000 - true_positives_11: 391.0000 - accuracy: 0.7483 - precision_11: 0.7622 - recall_11: 0.9310 - val_loss: 0.5059 - val_false_negatives_11: 8.0000 - val_false_positives_11: 43.0000 - val_true_negatives_11: 18.0000 - val_true_positives_11: 131.0000 - val_accuracy: 0.7450 - val_precision_11: 0.7529 - val_recall_11: 0.9424
# Epoch 13/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5140 - false_negatives_11: 34.0000 - false_positives_11: 121.0000 - true_negatives_11: 59.0000 - true_positives_11: 386.0000 - accuracy: 0.7417 - precision_11: 0.7613 - recall_11: 0.9190 - val_loss: 0.5047 - val_false_negatives_11: 7.0000 - val_false_positives_11: 42.0000 - val_true_negatives_11: 19.0000 - val_true_positives_11: 132.0000 - val_accuracy: 0.7550 - val_precision_11: 0.7586 - val_recall_11: 0.9496
# Epoch 14/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5025 - false_negatives_11: 34.0000 - false_positives_11: 121.0000 - true_negatives_11: 59.0000 - true_positives_11: 386.0000 - accuracy: 0.7417 - precision_11: 0.7613 - recall_11: 0.9190 - val_loss: 0.5038 - val_false_negatives_11: 7.0000 - val_false_positives_11: 41.0000 - val_true_negatives_11: 20.0000 - val_true_positives_11: 132.0000 - val_accuracy: 0.7600 - val_precision_11: 0.7630 - val_recall_11: 0.9496
# Epoch 15/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5006 - false_negatives_11: 34.0000 - false_positives_11: 116.0000 - true_negatives_11: 64.0000 - true_positives_11: 386.0000 - accuracy: 0.7500 - precision_11: 0.7689 - recall_11: 0.9190 - val_loss: 0.5034 - val_false_negatives_11: 7.0000 - val_false_positives_11: 40.0000 - val_true_negatives_11: 21.0000 - val_true_positives_11: 132.0000 - val_accuracy: 0.7650 - val_precision_11: 0.7674 - val_recall_11: 0.9496
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_sex'
#
# List of numeric features for this dataset: ['age', 'job', 'credit_amount', 'duration']
# List of non-numeric features: ['housing', 'saving_accounts', 'checking_account', 'purpose']
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.2s finished
# Training the model:
# Epoch 1/15
# 3/3 [==============================] - 2s 349ms/step - loss: 0.6733 - false_negatives_12: 149.0000 - false_positives_12: 103.0000 - true_negatives_12: 77.0000 - true_positives_12: 271.0000 - accuracy: 0.5800 - precision_12: 0.7246 - recall_12: 0.6452 - val_loss: 0.6442 - val_false_negatives_12: 19.0000 - val_false_positives_12: 45.0000 - val_true_negatives_12: 16.0000 - val_true_positives_12: 120.0000 - val_accuracy: 0.6800 - val_precision_12: 0.7273 - val_recall_12: 0.8633
# Epoch 2/15
# 3/3 [==============================] - 0s 54ms/step - loss: 0.6274 - false_negatives_12: 72.0000 - false_positives_12: 136.0000 - true_negatives_12: 44.0000 - true_positives_12: 348.0000 - accuracy: 0.6533 - precision_12: 0.7190 - recall_12: 0.8286 - val_loss: 0.6221 - val_false_negatives_12: 9.0000 - val_false_positives_12: 55.0000 - val_true_negatives_12: 6.0000 - val_true_positives_12: 130.0000 - val_accuracy: 0.6800 - val_precision_12: 0.7027 - val_recall_12: 0.9353
# Epoch 3/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.6119 - false_negatives_12: 29.0000 - false_positives_12: 153.0000 - true_negatives_12: 27.0000 - true_positives_12: 391.0000 - accuracy: 0.6967 - precision_12: 0.7188 - recall_12: 0.9310 - val_loss: 0.6073 - val_false_negatives_12: 2.0000 - val_false_positives_12: 55.0000 - val_true_negatives_12: 6.0000 - val_true_positives_12: 137.0000 - val_accuracy: 0.7150 - val_precision_12: 0.7135 - val_recall_12: 0.9856
# Epoch 4/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.6012 - false_negatives_12: 16.0000 - false_positives_12: 153.0000 - true_negatives_12: 27.0000 - true_positives_12: 404.0000 - accuracy: 0.7183 - precision_12: 0.7253 - recall_12: 0.9619 - val_loss: 0.5918 - val_false_negatives_12: 2.0000 - val_false_positives_12: 55.0000 - val_true_negatives_12: 6.0000 - val_true_positives_12: 137.0000 - val_accuracy: 0.7150 - val_precision_12: 0.7135 - val_recall_12: 0.9856
# Epoch 5/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5801 - false_negatives_12: 15.0000 - false_positives_12: 157.0000 - true_negatives_12: 23.0000 - true_positives_12: 405.0000 - accuracy: 0.7133 - precision_12: 0.7206 - recall_12: 0.9643 - val_loss: 0.5760 - val_false_negatives_12: 2.0000 - val_false_positives_12: 52.0000 - val_true_negatives_12: 9.0000 - val_true_positives_12: 137.0000 - val_accuracy: 0.7300 - val_precision_12: 0.7249 - val_recall_12: 0.9856
# Epoch 6/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.5669 - false_negatives_12: 24.0000 - false_positives_12: 140.0000 - true_negatives_12: 40.0000 - true_positives_12: 396.0000 - accuracy: 0.7267 - precision_12: 0.7388 - recall_12: 0.9429 - val_loss: 0.5629 - val_false_negatives_12: 3.0000 - val_false_positives_12: 46.0000 - val_true_negatives_12: 15.0000 - val_true_positives_12: 136.0000 - val_accuracy: 0.7550 - val_precision_12: 0.7473 - val_recall_12: 0.9784
# Epoch 7/15
# 3/3 [==============================] - 0s 54ms/step - loss: 0.5512 - false_negatives_12: 31.0000 - false_positives_12: 138.0000 - true_negatives_12: 42.0000 - true_positives_12: 389.0000 - accuracy: 0.7183 - precision_12: 0.7381 - recall_12: 0.9262 - val_loss: 0.5536 - val_false_negatives_12: 7.0000 - val_false_positives_12: 44.0000 - val_true_negatives_12: 17.0000 - val_true_positives_12: 132.0000 - val_accuracy: 0.7450 - val_precision_12: 0.7500 - val_recall_12: 0.9496
# Epoch 8/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5506 - false_negatives_12: 29.0000 - false_positives_12: 124.0000 - true_negatives_12: 56.0000 - true_positives_12: 391.0000 - accuracy: 0.7450 - precision_12: 0.7592 - recall_12: 0.9310 - val_loss: 0.5468 - val_false_negatives_12: 8.0000 - val_false_positives_12: 44.0000 - val_true_negatives_12: 17.0000 - val_true_positives_12: 131.0000 - val_accuracy: 0.7400 - val_precision_12: 0.7486 - val_recall_12: 0.9424
# Epoch 9/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5493 - false_negatives_12: 39.0000 - false_positives_12: 123.0000 - true_negatives_12: 57.0000 - true_positives_12: 381.0000 - accuracy: 0.7300 - precision_12: 0.7560 - recall_12: 0.9071 - val_loss: 0.5414 - val_false_negatives_12: 8.0000 - val_false_positives_12: 46.0000 - val_true_negatives_12: 15.0000 - val_true_positives_12: 131.0000 - val_accuracy: 0.7300 - val_precision_12: 0.7401 - val_recall_12: 0.9424
# Epoch 10/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5400 - false_negatives_12: 37.0000 - false_positives_12: 120.0000 - true_negatives_12: 60.0000 - true_positives_12: 383.0000 - accuracy: 0.7383 - precision_12: 0.7614 - recall_12: 0.9119 - val_loss: 0.5381 - val_false_negatives_12: 8.0000 - val_false_positives_12: 46.0000 - val_true_negatives_12: 15.0000 - val_true_positives_12: 131.0000 - val_accuracy: 0.7300 - val_precision_12: 0.7401 - val_recall_12: 0.9424
# Epoch 11/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5196 - false_negatives_12: 27.0000 - false_positives_12: 115.0000 - true_negatives_12: 65.0000 - true_positives_12: 393.0000 - accuracy: 0.7633 - precision_12: 0.7736 - recall_12: 0.9357 - val_loss: 0.5368 - val_false_negatives_12: 7.0000 - val_false_positives_12: 46.0000 - val_true_negatives_12: 15.0000 - val_true_positives_12: 132.0000 - val_accuracy: 0.7350 - val_precision_12: 0.7416 - val_recall_12: 0.9496
# Epoch 12/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5202 - false_negatives_12: 24.0000 - false_positives_12: 124.0000 - true_negatives_12: 56.0000 - true_positives_12: 396.0000 - accuracy: 0.7533 - precision_12: 0.7615 - recall_12: 0.9429 - val_loss: 0.5361 - val_false_negatives_12: 6.0000 - val_false_positives_12: 46.0000 - val_true_negatives_12: 15.0000 - val_true_positives_12: 133.0000 - val_accuracy: 0.7400 - val_precision_12: 0.7430 - val_recall_12: 0.9568
# Epoch 13/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5112 - false_negatives_12: 21.0000 - false_positives_12: 112.0000 - true_negatives_12: 68.0000 - true_positives_12: 399.0000 - accuracy: 0.7783 - precision_12: 0.7808 - recall_12: 0.9500 - val_loss: 0.5343 - val_false_negatives_12: 6.0000 - val_false_positives_12: 45.0000 - val_true_negatives_12: 16.0000 - val_true_positives_12: 133.0000 - val_accuracy: 0.7450 - val_precision_12: 0.7472 - val_recall_12: 0.9568
# Epoch 14/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5244 - false_negatives_12: 29.0000 - false_positives_12: 125.0000 - true_negatives_12: 55.0000 - true_positives_12: 391.0000 - accuracy: 0.7433 - precision_12: 0.7578 - recall_12: 0.9310 - val_loss: 0.5321 - val_false_negatives_12: 7.0000 - val_false_positives_12: 42.0000 - val_true_negatives_12: 19.0000 - val_true_positives_12: 132.0000 - val_accuracy: 0.7550 - val_precision_12: 0.7586 - val_recall_12: 0.9496
# Epoch 15/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5092 - false_negatives_12: 31.0000 - false_positives_12: 115.0000 - true_negatives_12: 65.0000 - true_positives_12: 389.0000 - accuracy: 0.7567 - precision_12: 0.7718 - recall_12: 0.9262 - val_loss: 0.5308 - val_false_negatives_12: 9.0000 - val_false_positives_12: 40.0000 - val_true_negatives_12: 21.0000 - val_true_positives_12: 130.0000 - val_accuracy: 0.7550 - val_precision_12: 0.7647 - val_recall_12: 0.9353
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 5ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 4ms/step
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_job'
#
# List of numeric features for this dataset: ['age', 'credit_amount', 'duration']
# List of non-numeric features: ['sex', 'housing', 'saving_accounts', 'checking_account', 'purpose']
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# Training the model:
# Epoch 1/15
# 3/3 [==============================] - 2s 354ms/step - loss: 0.7057 - false_negatives_13: 91.0000 - false_positives_13: 162.0000 - true_negatives_13: 18.0000 - true_positives_13: 329.0000 - accuracy: 0.5783 - precision_13: 0.6701 - recall_13: 0.7833 - val_loss: 0.6573 - val_false_negatives_13: 10.0000 - val_false_positives_13: 57.0000 - val_true_negatives_13: 4.0000 - val_true_positives_13: 129.0000 - val_accuracy: 0.6650 - val_precision_13: 0.6935 - val_recall_13: 0.9281
# Epoch 2/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.6632 - false_negatives_13: 46.0000 - false_positives_13: 163.0000 - true_negatives_13: 17.0000 - true_positives_13: 374.0000 - accuracy: 0.6517 - precision_13: 0.6965 - recall_13: 0.8905 - val_loss: 0.6229 - val_false_negatives_13: 5.0000 - val_false_positives_13: 54.0000 - val_true_negatives_13: 7.0000 - val_true_positives_13: 134.0000 - val_accuracy: 0.7050 - val_precision_13: 0.7128 - val_recall_13: 0.9640
# Epoch 3/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.6332 - false_negatives_13: 23.0000 - false_positives_13: 161.0000 - true_negatives_13: 19.0000 - true_positives_13: 397.0000 - accuracy: 0.6933 - precision_13: 0.7115 - recall_13: 0.9452 - val_loss: 0.5951 - val_false_negatives_13: 4.0000 - val_false_positives_13: 54.0000 - val_true_negatives_13: 7.0000 - val_true_positives_13: 135.0000 - val_accuracy: 0.7100 - val_precision_13: 0.7143 - val_recall_13: 0.9712
# Epoch 4/15
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6132 - false_negatives_13: 23.0000 - false_positives_13: 159.0000 - true_negatives_13: 21.0000 - true_positives_13: 397.0000 - accuracy: 0.6967 - precision_13: 0.7140 - recall_13: 0.9452 - val_loss: 0.5725 - val_false_negatives_13: 3.0000 - val_false_positives_13: 55.0000 - val_true_negatives_13: 6.0000 - val_true_positives_13: 136.0000 - val_accuracy: 0.7100 - val_precision_13: 0.7120 - val_recall_13: 0.9784
# Epoch 5/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5910 - false_negatives_13: 23.0000 - false_positives_13: 152.0000 - true_negatives_13: 28.0000 - true_positives_13: 397.0000 - accuracy: 0.7083 - precision_13: 0.7231 - recall_13: 0.9452 - val_loss: 0.5540 - val_false_negatives_13: 3.0000 - val_false_positives_13: 53.0000 - val_true_negatives_13: 8.0000 - val_true_positives_13: 136.0000 - val_accuracy: 0.7200 - val_precision_13: 0.7196 - val_recall_13: 0.9784
# Epoch 6/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5674 - false_negatives_13: 26.0000 - false_positives_13: 141.0000 - true_negatives_13: 39.0000 - true_positives_13: 394.0000 - accuracy: 0.7217 - precision_13: 0.7364 - recall_13: 0.9381 - val_loss: 0.5393 - val_false_negatives_13: 5.0000 - val_false_positives_13: 48.0000 - val_true_negatives_13: 13.0000 - val_true_positives_13: 134.0000 - val_accuracy: 0.7350 - val_precision_13: 0.7363 - val_recall_13: 0.9640
# Epoch 7/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5575 - false_negatives_13: 32.0000 - false_positives_13: 142.0000 - true_negatives_13: 38.0000 - true_positives_13: 388.0000 - accuracy: 0.7100 - precision_13: 0.7321 - recall_13: 0.9238 - val_loss: 0.5274 - val_false_negatives_13: 7.0000 - val_false_positives_13: 46.0000 - val_true_negatives_13: 15.0000 - val_true_positives_13: 132.0000 - val_accuracy: 0.7350 - val_precision_13: 0.7416 - val_recall_13: 0.9496
# Epoch 8/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5508 - false_negatives_13: 27.0000 - false_positives_13: 133.0000 - true_negatives_13: 47.0000 - true_positives_13: 393.0000 - accuracy: 0.7333 - precision_13: 0.7471 - recall_13: 0.9357 - val_loss: 0.5176 - val_false_negatives_13: 8.0000 - val_false_positives_13: 42.0000 - val_true_negatives_13: 19.0000 - val_true_positives_13: 131.0000 - val_accuracy: 0.7500 - val_precision_13: 0.7572 - val_recall_13: 0.9424
# Epoch 9/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5303 - false_negatives_13: 25.0000 - false_positives_13: 125.0000 - true_negatives_13: 55.0000 - true_positives_13: 395.0000 - accuracy: 0.7500 - precision_13: 0.7596 - recall_13: 0.9405 - val_loss: 0.5096 - val_false_negatives_13: 8.0000 - val_false_positives_13: 40.0000 - val_true_negatives_13: 21.0000 - val_true_positives_13: 131.0000 - val_accuracy: 0.7600 - val_precision_13: 0.7661 - val_recall_13: 0.9424
# Epoch 10/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5253 - false_negatives_13: 30.0000 - false_positives_13: 123.0000 - true_negatives_13: 57.0000 - true_positives_13: 390.0000 - accuracy: 0.7450 - precision_13: 0.7602 - recall_13: 0.9286 - val_loss: 0.5036 - val_false_negatives_13: 10.0000 - val_false_positives_13: 37.0000 - val_true_negatives_13: 24.0000 - val_true_positives_13: 129.0000 - val_accuracy: 0.7650 - val_precision_13: 0.7771 - val_recall_13: 0.9281
# Epoch 11/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5181 - false_negatives_13: 32.0000 - false_positives_13: 119.0000 - true_negatives_13: 61.0000 - true_positives_13: 388.0000 - accuracy: 0.7483 - precision_13: 0.7653 - recall_13: 0.9238 - val_loss: 0.4989 - val_false_negatives_13: 10.0000 - val_false_positives_13: 38.0000 - val_true_negatives_13: 23.0000 - val_true_positives_13: 129.0000 - val_accuracy: 0.7600 - val_precision_13: 0.7725 - val_recall_13: 0.9281
# Epoch 12/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5177 - false_negatives_13: 34.0000 - false_positives_13: 119.0000 - true_negatives_13: 61.0000 - true_positives_13: 386.0000 - accuracy: 0.7450 - precision_13: 0.7644 - recall_13: 0.9190 - val_loss: 0.4952 - val_false_negatives_13: 10.0000 - val_false_positives_13: 38.0000 - val_true_negatives_13: 23.0000 - val_true_positives_13: 129.0000 - val_accuracy: 0.7600 - val_precision_13: 0.7725 - val_recall_13: 0.9281
# Epoch 13/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.5153 - false_negatives_13: 32.0000 - false_positives_13: 120.0000 - true_negatives_13: 60.0000 - true_positives_13: 388.0000 - accuracy: 0.7467 - precision_13: 0.7638 - recall_13: 0.9238 - val_loss: 0.4920 - val_false_negatives_13: 10.0000 - val_false_positives_13: 35.0000 - val_true_negatives_13: 26.0000 - val_true_positives_13: 129.0000 - val_accuracy: 0.7750 - val_precision_13: 0.7866 - val_recall_13: 0.9281
# Epoch 14/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5082 - false_negatives_13: 34.0000 - false_positives_13: 112.0000 - true_negatives_13: 68.0000 - true_positives_13: 386.0000 - accuracy: 0.7567 - precision_13: 0.7751 - recall_13: 0.9190 - val_loss: 0.4892 - val_false_negatives_13: 11.0000 - val_false_positives_13: 35.0000 - val_true_negatives_13: 26.0000 - val_true_positives_13: 128.0000 - val_accuracy: 0.7700 - val_precision_13: 0.7853 - val_recall_13: 0.9209
# Epoch 15/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5075 - false_negatives_13: 35.0000 - false_positives_13: 111.0000 - true_negatives_13: 69.0000 - true_positives_13: 385.0000 - accuracy: 0.7567 - precision_13: 0.7762 - recall_13: 0.9167 - val_loss: 0.4871 - val_false_negatives_13: 12.0000 - val_false_positives_13: 35.0000 - val_true_negatives_13: 26.0000 - val_true_positives_13: 127.0000 - val_accuracy: 0.7650 - val_precision_13: 0.7840 - val_recall_13: 0.9137
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 61ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 5ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_housing'
#
# List of numeric features for this dataset: ['age', 'job', 'credit_amount', 'duration']
# List of non-numeric features: ['sex', 'saving_accounts', 'checking_account', 'purpose']
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.7s finished
# Training the model:
# Epoch 1/15
# 3/3 [==============================] - 2s 358ms/step - loss: 0.7974 - false_negatives_14: 259.0000 - false_positives_14: 69.0000 - true_negatives_14: 111.0000 - true_positives_14: 161.0000 - accuracy: 0.4533 - precision_14: 0.7000 - recall_14: 0.3833 - val_loss: 0.7230 - val_false_negatives_14: 67.0000 - val_false_positives_14: 31.0000 - val_true_negatives_14: 30.0000 - val_true_positives_14: 72.0000 - val_accuracy: 0.5100 - val_precision_14: 0.6990 - val_recall_14: 0.5180
# Epoch 2/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.6993 - false_negatives_14: 165.0000 - false_positives_14: 100.0000 - true_negatives_14: 80.0000 - true_positives_14: 255.0000 - accuracy: 0.5583 - precision_14: 0.7183 - recall_14: 0.6071 - val_loss: 0.6643 - val_false_negatives_14: 38.0000 - val_false_positives_14: 43.0000 - val_true_negatives_14: 18.0000 - val_true_positives_14: 101.0000 - val_accuracy: 0.5950 - val_precision_14: 0.7014 - val_recall_14: 0.7266
# Epoch 3/15
# 3/3 [==============================] - 0s 55ms/step - loss: 0.6576 - false_negatives_14: 88.0000 - false_positives_14: 135.0000 - true_negatives_14: 45.0000 - true_positives_14: 332.0000 - accuracy: 0.6283 - precision_14: 0.7109 - recall_14: 0.7905 - val_loss: 0.6275 - val_false_negatives_14: 11.0000 - val_false_positives_14: 53.0000 - val_true_negatives_14: 8.0000 - val_true_positives_14: 128.0000 - val_accuracy: 0.6800 - val_precision_14: 0.7072 - val_recall_14: 0.9209
# Epoch 4/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.6178 - false_negatives_14: 38.0000 - false_positives_14: 148.0000 - true_negatives_14: 32.0000 - true_positives_14: 382.0000 - accuracy: 0.6900 - precision_14: 0.7208 - recall_14: 0.9095 - val_loss: 0.6045 - val_false_negatives_14: 4.0000 - val_false_positives_14: 56.0000 - val_true_negatives_14: 5.0000 - val_true_positives_14: 135.0000 - val_accuracy: 0.7000 - val_precision_14: 0.7068 - val_recall_14: 0.9712
# Epoch 5/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5955 - false_negatives_14: 20.0000 - false_positives_14: 155.0000 - true_negatives_14: 25.0000 - true_positives_14: 400.0000 - accuracy: 0.7083 - precision_14: 0.7207 - recall_14: 0.9524 - val_loss: 0.5882 - val_false_negatives_14: 2.0000 - val_false_positives_14: 57.0000 - val_true_negatives_14: 4.0000 - val_true_positives_14: 137.0000 - val_accuracy: 0.7050 - val_precision_14: 0.7062 - val_recall_14: 0.9856
# Epoch 6/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5739 - false_negatives_14: 12.0000 - false_positives_14: 159.0000 - true_negatives_14: 21.0000 - true_positives_14: 408.0000 - accuracy: 0.7150 - precision_14: 0.7196 - recall_14: 0.9714 - val_loss: 0.5748 - val_false_negatives_14: 3.0000 - val_false_positives_14: 52.0000 - val_true_negatives_14: 9.0000 - val_true_positives_14: 136.0000 - val_accuracy: 0.7250 - val_precision_14: 0.7234 - val_recall_14: 0.9784
# Epoch 7/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5690 - false_negatives_14: 9.0000 - false_positives_14: 156.0000 - true_negatives_14: 24.0000 - true_positives_14: 411.0000 - accuracy: 0.7250 - precision_14: 0.7249 - recall_14: 0.9786 - val_loss: 0.5630 - val_false_negatives_14: 6.0000 - val_false_positives_14: 49.0000 - val_true_negatives_14: 12.0000 - val_true_positives_14: 133.0000 - val_accuracy: 0.7250 - val_precision_14: 0.7308 - val_recall_14: 0.9568
# Epoch 8/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5497 - false_negatives_14: 21.0000 - false_positives_14: 147.0000 - true_negatives_14: 33.0000 - true_positives_14: 399.0000 - accuracy: 0.7200 - precision_14: 0.7308 - recall_14: 0.9500 - val_loss: 0.5531 - val_false_negatives_14: 6.0000 - val_false_positives_14: 45.0000 - val_true_negatives_14: 16.0000 - val_true_positives_14: 133.0000 - val_accuracy: 0.7450 - val_precision_14: 0.7472 - val_recall_14: 0.9568
# Epoch 9/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5469 - false_negatives_14: 28.0000 - false_positives_14: 141.0000 - true_negatives_14: 39.0000 - true_positives_14: 392.0000 - accuracy: 0.7183 - precision_14: 0.7355 - recall_14: 0.9333 - val_loss: 0.5450 - val_false_negatives_14: 9.0000 - val_false_positives_14: 45.0000 - val_true_negatives_14: 16.0000 - val_true_positives_14: 130.0000 - val_accuracy: 0.7300 - val_precision_14: 0.7429 - val_recall_14: 0.9353
# Epoch 10/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5391 - false_negatives_14: 29.0000 - false_positives_14: 134.0000 - true_negatives_14: 46.0000 - true_positives_14: 391.0000 - accuracy: 0.7283 - precision_14: 0.7448 - recall_14: 0.9310 - val_loss: 0.5380 - val_false_negatives_14: 10.0000 - val_false_positives_14: 45.0000 - val_true_negatives_14: 16.0000 - val_true_positives_14: 129.0000 - val_accuracy: 0.7250 - val_precision_14: 0.7414 - val_recall_14: 0.9281
# Epoch 11/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5325 - false_negatives_14: 29.0000 - false_positives_14: 128.0000 - true_negatives_14: 52.0000 - true_positives_14: 391.0000 - accuracy: 0.7383 - precision_14: 0.7534 - recall_14: 0.9310 - val_loss: 0.5316 - val_false_negatives_14: 10.0000 - val_false_positives_14: 44.0000 - val_true_negatives_14: 17.0000 - val_true_positives_14: 129.0000 - val_accuracy: 0.7300 - val_precision_14: 0.7457 - val_recall_14: 0.9281
# Epoch 12/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5245 - false_negatives_14: 33.0000 - false_positives_14: 129.0000 - true_negatives_14: 51.0000 - true_positives_14: 387.0000 - accuracy: 0.7300 - precision_14: 0.7500 - recall_14: 0.9214 - val_loss: 0.5258 - val_false_negatives_14: 9.0000 - val_false_positives_14: 44.0000 - val_true_negatives_14: 17.0000 - val_true_positives_14: 130.0000 - val_accuracy: 0.7350 - val_precision_14: 0.7471 - val_recall_14: 0.9353
# Epoch 13/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5200 - false_negatives_14: 30.0000 - false_positives_14: 126.0000 - true_negatives_14: 54.0000 - true_positives_14: 390.0000 - accuracy: 0.7400 - precision_14: 0.7558 - recall_14: 0.9286 - val_loss: 0.5207 - val_false_negatives_14: 9.0000 - val_false_positives_14: 42.0000 - val_true_negatives_14: 19.0000 - val_true_positives_14: 130.0000 - val_accuracy: 0.7450 - val_precision_14: 0.7558 - val_recall_14: 0.9353
# Epoch 14/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5158 - false_negatives_14: 30.0000 - false_positives_14: 117.0000 - true_negatives_14: 63.0000 - true_positives_14: 390.0000 - accuracy: 0.7550 - precision_14: 0.7692 - recall_14: 0.9286 - val_loss: 0.5163 - val_false_negatives_14: 7.0000 - val_false_positives_14: 41.0000 - val_true_negatives_14: 20.0000 - val_true_positives_14: 132.0000 - val_accuracy: 0.7600 - val_precision_14: 0.7630 - val_recall_14: 0.9496
# Epoch 15/15
# 3/3 [==============================] - 0s 49ms/step - loss: 0.5024 - false_negatives_14: 27.0000 - false_positives_14: 121.0000 - true_negatives_14: 59.0000 - true_positives_14: 393.0000 - accuracy: 0.7533 - precision_14: 0.7646 - recall_14: 0.9357 - val_loss: 0.5125 - val_false_negatives_14: 7.0000 - val_false_positives_14: 41.0000 - val_true_negatives_14: 20.0000 - val_true_positives_14: 132.0000 - val_accuracy: 0.7600 - val_precision_14: 0.7630 - val_recall_14: 0.9496
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 57ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 89ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_saving_accounts'
#
# List of numeric features for this dataset: ['age', 'job', 'credit_amount', 'duration']
# List of non-numeric features: ['sex', 'housing', 'checking_account', 'purpose']
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.8s finished
# Training the model:
# Epoch 1/15
# 3/3 [==============================] - 2s 356ms/step - loss: 0.7100 - false_negatives_15: 171.0000 - false_positives_15: 114.0000 - true_negatives_15: 66.0000 - true_positives_15: 249.0000 - accuracy: 0.5250 - precision_15: 0.6860 - recall_15: 0.5929 - val_loss: 0.6580 - val_false_negatives_15: 24.0000 - val_false_positives_15: 43.0000 - val_true_negatives_15: 18.0000 - val_true_positives_15: 115.0000 - val_accuracy: 0.6650 - val_precision_15: 0.7278 - val_recall_15: 0.8273
# Epoch 2/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.6670 - false_negatives_15: 72.0000 - false_positives_15: 144.0000 - true_negatives_15: 36.0000 - true_positives_15: 348.0000 - accuracy: 0.6400 - precision_15: 0.7073 - recall_15: 0.8286 - val_loss: 0.6232 - val_false_negatives_15: 5.0000 - val_false_positives_15: 52.0000 - val_true_negatives_15: 9.0000 - val_true_positives_15: 134.0000 - val_accuracy: 0.7150 - val_precision_15: 0.7204 - val_recall_15: 0.9640
# Epoch 3/15
# 3/3 [==============================] - 0s 54ms/step - loss: 0.6308 - false_negatives_15: 33.0000 - false_positives_15: 158.0000 - true_negatives_15: 22.0000 - true_positives_15: 387.0000 - accuracy: 0.6817 - precision_15: 0.7101 - recall_15: 0.9214 - val_loss: 0.5996 - val_false_negatives_15: 3.0000 - val_false_positives_15: 51.0000 - val_true_negatives_15: 10.0000 - val_true_positives_15: 136.0000 - val_accuracy: 0.7300 - val_precision_15: 0.7273 - val_recall_15: 0.9784
# Epoch 4/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.6055 - false_negatives_15: 20.0000 - false_positives_15: 155.0000 - true_negatives_15: 25.0000 - true_positives_15: 400.0000 - accuracy: 0.7083 - precision_15: 0.7207 - recall_15: 0.9524 - val_loss: 0.5832 - val_false_negatives_15: 1.0000 - val_false_positives_15: 54.0000 - val_true_negatives_15: 7.0000 - val_true_positives_15: 138.0000 - val_accuracy: 0.7250 - val_precision_15: 0.7188 - val_recall_15: 0.9928
# Epoch 5/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5891 - false_negatives_15: 13.0000 - false_positives_15: 153.0000 - true_negatives_15: 27.0000 - true_positives_15: 407.0000 - accuracy: 0.7233 - precision_15: 0.7268 - recall_15: 0.9690 - val_loss: 0.5709 - val_false_negatives_15: 2.0000 - val_false_positives_15: 53.0000 - val_true_negatives_15: 8.0000 - val_true_positives_15: 137.0000 - val_accuracy: 0.7250 - val_precision_15: 0.7211 - val_recall_15: 0.9856
# Epoch 6/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5722 - false_negatives_15: 15.0000 - false_positives_15: 145.0000 - true_negatives_15: 35.0000 - true_positives_15: 405.0000 - accuracy: 0.7333 - precision_15: 0.7364 - recall_15: 0.9643 - val_loss: 0.5610 - val_false_negatives_15: 4.0000 - val_false_positives_15: 53.0000 - val_true_negatives_15: 8.0000 - val_true_positives_15: 135.0000 - val_accuracy: 0.7150 - val_precision_15: 0.7181 - val_recall_15: 0.9712
# Epoch 7/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5779 - false_negatives_15: 21.0000 - false_positives_15: 147.0000 - true_negatives_15: 33.0000 - true_positives_15: 399.0000 - accuracy: 0.7200 - precision_15: 0.7308 - recall_15: 0.9500 - val_loss: 0.5527 - val_false_negatives_15: 4.0000 - val_false_positives_15: 52.0000 - val_true_negatives_15: 9.0000 - val_true_positives_15: 135.0000 - val_accuracy: 0.7200 - val_precision_15: 0.7219 - val_recall_15: 0.9712
# Epoch 8/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5627 - false_negatives_15: 28.0000 - false_positives_15: 140.0000 - true_negatives_15: 40.0000 - true_positives_15: 392.0000 - accuracy: 0.7200 - precision_15: 0.7368 - recall_15: 0.9333 - val_loss: 0.5455 - val_false_negatives_15: 5.0000 - val_false_positives_15: 49.0000 - val_true_negatives_15: 12.0000 - val_true_positives_15: 134.0000 - val_accuracy: 0.7300 - val_precision_15: 0.7322 - val_recall_15: 0.9640
# Epoch 9/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5607 - false_negatives_15: 31.0000 - false_positives_15: 138.0000 - true_negatives_15: 42.0000 - true_positives_15: 389.0000 - accuracy: 0.7183 - precision_15: 0.7381 - recall_15: 0.9262 - val_loss: 0.5387 - val_false_negatives_15: 6.0000 - val_false_positives_15: 47.0000 - val_true_negatives_15: 14.0000 - val_true_positives_15: 133.0000 - val_accuracy: 0.7350 - val_precision_15: 0.7389 - val_recall_15: 0.9568
# Epoch 10/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5446 - false_negatives_15: 28.0000 - false_positives_15: 131.0000 - true_negatives_15: 49.0000 - true_positives_15: 392.0000 - accuracy: 0.7350 - precision_15: 0.7495 - recall_15: 0.9333 - val_loss: 0.5325 - val_false_negatives_15: 6.0000 - val_false_positives_15: 45.0000 - val_true_negatives_15: 16.0000 - val_true_positives_15: 133.0000 - val_accuracy: 0.7450 - val_precision_15: 0.7472 - val_recall_15: 0.9568
# Epoch 11/15
# ...
# Epoch 4/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5679 - false_negatives_18: 11.0000 - false_positives_18: 162.0000 - true_negatives_18: 18.0000 - true_positives_18: 409.0000 - accuracy: 0.7117 - precision_18: 0.7163 - recall_18: 0.9738 - val_loss: 0.5435 - val_false_negatives_18: 6.0000 - val_false_positives_18: 51.0000 - val_true_negatives_18: 10.0000 - val_true_positives_18: 133.0000 - val_accuracy: 0.7150 - val_precision_18: 0.7228 - val_recall_18: 0.9568
# Epoch 5/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5614 - false_negatives_18: 14.0000 - false_positives_18: 156.0000 - true_negatives_18: 24.0000 - true_positives_18: 406.0000 - accuracy: 0.7167 - precision_18: 0.7224 - recall_18: 0.9667 - val_loss: 0.5319 - val_false_negatives_18: 6.0000 - val_false_positives_18: 51.0000 - val_true_negatives_18: 10.0000 - val_true_positives_18: 133.0000 - val_accuracy: 0.7150 - val_precision_18: 0.7228 - val_recall_18: 0.9568
# Epoch 6/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5540 - false_negatives_18: 14.0000 - false_positives_18: 147.0000 - true_negatives_18: 33.0000 - true_positives_18: 406.0000 - accuracy: 0.7317 - precision_18: 0.7342 - recall_18: 0.9667 - val_loss: 0.5220 - val_false_negatives_18: 7.0000 - val_false_positives_18: 50.0000 - val_true_negatives_18: 11.0000 - val_true_positives_18: 132.0000 - val_accuracy: 0.7150 - val_precision_18: 0.7253 - val_recall_18: 0.9496
# Epoch 7/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5385 - false_negatives_18: 21.0000 - false_positives_18: 135.0000 - true_negatives_18: 45.0000 - true_positives_18: 399.0000 - accuracy: 0.7400 - precision_18: 0.7472 - recall_18: 0.9500 - val_loss: 0.5139 - val_false_negatives_18: 8.0000 - val_false_positives_18: 50.0000 - val_true_negatives_18: 11.0000 - val_true_positives_18: 131.0000 - val_accuracy: 0.7100 - val_precision_18: 0.7238 - val_recall_18: 0.9424
# Epoch 8/15
# 3/3 [==============================] - 0s 49ms/step - loss: 0.5366 - false_negatives_18: 24.0000 - false_positives_18: 134.0000 - true_negatives_18: 46.0000 - true_positives_18: 396.0000 - accuracy: 0.7367 - precision_18: 0.7472 - recall_18: 0.9429 - val_loss: 0.5071 - val_false_negatives_18: 9.0000 - val_false_positives_18: 46.0000 - val_true_negatives_18: 15.0000 - val_true_positives_18: 130.0000 - val_accuracy: 0.7250 - val_precision_18: 0.7386 - val_recall_18: 0.9353
# Epoch 9/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5339 - false_negatives_18: 25.0000 - false_positives_18: 128.0000 - true_negatives_18: 52.0000 - true_positives_18: 395.0000 - accuracy: 0.7450 - precision_18: 0.7553 - recall_18: 0.9405 - val_loss: 0.5016 - val_false_negatives_18: 8.0000 - val_false_positives_18: 44.0000 - val_true_negatives_18: 17.0000 - val_true_positives_18: 131.0000 - val_accuracy: 0.7400 - val_precision_18: 0.7486 - val_recall_18: 0.9424
# Epoch 10/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5266 - false_negatives_18: 30.0000 - false_positives_18: 128.0000 - true_negatives_18: 52.0000 - true_positives_18: 390.0000 - accuracy: 0.7367 - precision_18: 0.7529 - recall_18: 0.9286 - val_loss: 0.4972 - val_false_negatives_18: 8.0000 - val_false_positives_18: 44.0000 - val_true_negatives_18: 17.0000 - val_true_positives_18: 131.0000 - val_accuracy: 0.7400 - val_precision_18: 0.7486 - val_recall_18: 0.9424
# Epoch 11/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.5265 - false_negatives_18: 30.0000 - false_positives_18: 123.0000 - true_negatives_18: 57.0000 - true_positives_18: 390.0000 - accuracy: 0.7450 - precision_18: 0.7602 - recall_18: 0.9286 - val_loss: 0.4938 - val_false_negatives_18: 8.0000 - val_false_positives_18: 43.0000 - val_true_negatives_18: 18.0000 - val_true_positives_18: 131.0000 - val_accuracy: 0.7450 - val_precision_18: 0.7529 - val_recall_18: 0.9424
# Epoch 12/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.5205 - false_negatives_18: 26.0000 - false_positives_18: 119.0000 - true_negatives_18: 61.0000 - true_positives_18: 394.0000 - accuracy: 0.7583 - precision_18: 0.7680 - recall_18: 0.9381 - val_loss: 0.4911 - val_false_negatives_18: 8.0000 - val_false_positives_18: 42.0000 - val_true_negatives_18: 19.0000 - val_true_positives_18: 131.0000 - val_accuracy: 0.7500 - val_precision_18: 0.7572 - val_recall_18: 0.9424
# Epoch 13/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.5199 - false_negatives_18: 30.0000 - false_positives_18: 123.0000 - true_negatives_18: 57.0000 - true_positives_18: 390.0000 - accuracy: 0.7450 - precision_18: 0.7602 - recall_18: 0.9286 - val_loss: 0.4885 - val_false_negatives_18: 7.0000 - val_false_positives_18: 41.0000 - val_true_negatives_18: 20.0000 - val_true_positives_18: 132.0000 - val_accuracy: 0.7600 - val_precision_18: 0.7630 - val_recall_18: 0.9496
# Epoch 14/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.5132 - false_negatives_18: 26.0000 - false_positives_18: 119.0000 - true_negatives_18: 61.0000 - true_positives_18: 394.0000 - accuracy: 0.7583 - precision_18: 0.7680 - recall_18: 0.9381 - val_loss: 0.4862 - val_false_negatives_18: 7.0000 - val_false_positives_18: 41.0000 - val_true_negatives_18: 20.0000 - val_true_positives_18: 132.0000 - val_accuracy: 0.7600 - val_precision_18: 0.7630 - val_recall_18: 0.9496
# Epoch 15/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5069 - false_negatives_18: 26.0000 - false_positives_18: 115.0000 - true_negatives_18: 65.0000 - true_positives_18: 394.0000 - accuracy: 0.7650 - precision_18: 0.7741 - recall_18: 0.9381 - val_loss: 0.4843 - val_false_negatives_18: 7.0000 - val_false_positives_18: 41.0000 - val_true_negatives_18: 20.0000 - val_true_positives_18: 132.0000 - val_accuracy: 0.7600 - val_precision_18: 0.7630 - val_recall_18: 0.9496
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 55ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 189ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 4ms/step
# RUNNING ANALYSIS FOR TRAINING TYPE: 'remove_feature_purpose'
#
# List of numeric features for this dataset: ['age', 'job', 'credit_amount', 'duration']
# List of non-numeric features: ['sex', 'housing', 'saving_accounts', 'checking_account']
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.7s finished
# Training the model:
# Epoch 1/15
# 3/3 [==============================] - 2s 370ms/step - loss: 1.1806 - false_negatives_19: 410.0000 - false_positives_19: 10.0000 - true_negatives_19: 170.0000 - true_positives_19: 10.0000 - accuracy: 0.3000 - precision_19: 0.5000 - recall_19: 0.0238 - val_loss: 1.0689 - val_false_negatives_19: 134.0000 - val_false_positives_19: 8.0000 - val_true_negatives_19: 53.0000 - val_true_positives_19: 5.0000 - val_accuracy: 0.2900 - val_precision_19: 0.3846 - val_recall_19: 0.0360
# Epoch 2/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.9684 - false_negatives_19: 377.0000 - false_positives_19: 29.0000 - true_negatives_19: 151.0000 - true_positives_19: 43.0000 - accuracy: 0.3233 - precision_19: 0.5972 - recall_19: 0.1024 - val_loss: 0.9066 - val_false_negatives_19: 118.0000 - val_false_positives_19: 18.0000 - val_true_negatives_19: 43.0000 - val_true_positives_19: 21.0000 - val_accuracy: 0.3200 - val_precision_19: 0.5385 - val_recall_19: 0.1511
# Epoch 3/15
# 3/3 [==============================] - 0s 215ms/step - loss: 0.8368 - false_negatives_19: 303.0000 - false_positives_19: 69.0000 - true_negatives_19: 111.0000 - true_positives_19: 117.0000 - accuracy: 0.3800 - precision_19: 0.6290 - recall_19: 0.2786 - val_loss: 0.7930 - val_false_negatives_19: 93.0000 - val_false_positives_19: 29.0000 - val_true_negatives_19: 32.0000 - val_true_positives_19: 46.0000 - val_accuracy: 0.3900 - val_precision_19: 0.6133 - val_recall_19: 0.3309
# Epoch 4/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.7485 - false_negatives_19: 209.0000 - false_positives_19: 104.0000 - true_negatives_19: 76.0000 - true_positives_19: 211.0000 - accuracy: 0.4783 - precision_19: 0.6698 - recall_19: 0.5024 - val_loss: 0.7222 - val_false_negatives_19: 49.0000 - val_false_positives_19: 45.0000 - val_true_negatives_19: 16.0000 - val_true_positives_19: 90.0000 - val_accuracy: 0.5300 - val_precision_19: 0.6667 - val_recall_19: 0.6475
# Epoch 5/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.6892 - false_negatives_19: 101.0000 - false_positives_19: 137.0000 - true_negatives_19: 43.0000 - true_positives_19: 319.0000 - accuracy: 0.6033 - precision_19: 0.6996 - recall_19: 0.7595 - val_loss: 0.6809 - val_false_negatives_19: 15.0000 - val_false_positives_19: 55.0000 - val_true_negatives_19: 6.0000 - val_true_positives_19: 124.0000 - val_accuracy: 0.6500 - val_precision_19: 0.6927 - val_recall_19: 0.8921
# Epoch 6/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.6559 - false_negatives_19: 40.0000 - false_positives_19: 164.0000 - true_negatives_19: 16.0000 - true_positives_19: 380.0000 - accuracy: 0.6600 - precision_19: 0.6985 - recall_19: 0.9048 - val_loss: 0.6564 - val_false_negatives_19: 5.0000 - val_false_positives_19: 60.0000 - val_true_negatives_19: 1.0000 - val_true_positives_19: 134.0000 - val_accuracy: 0.6750 - val_precision_19: 0.6907 - val_recall_19: 0.9640
# Epoch 7/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.6472 - false_negatives_19: 15.0000 - false_positives_19: 174.0000 - true_negatives_19: 6.0000 - true_positives_19: 405.0000 - accuracy: 0.6850 - precision_19: 0.6995 - recall_19: 0.9643 - val_loss: 0.6389 - val_false_negatives_19: 0.0000e+00 - val_false_positives_19: 61.0000 - val_true_negatives_19: 0.0000e+00 - val_true_positives_19: 139.0000 - val_accuracy: 0.6950 - val_precision_19: 0.6950 - val_recall_19: 1.0000
# Epoch 8/15
# 3/3 [==============================] - 0s 50ms/step - loss: 0.6199 - false_negatives_19: 9.0000 - false_positives_19: 177.0000 - true_negatives_19: 3.0000 - true_positives_19: 411.0000 - accuracy: 0.6900 - precision_19: 0.6990 - recall_19: 0.9786 - val_loss: 0.6231 - val_false_negatives_19: 0.0000e+00 - val_false_positives_19: 61.0000 - val_true_negatives_19: 0.0000e+00 - val_true_positives_19: 139.0000 - val_accuracy: 0.6950 - val_precision_19: 0.6950 - val_recall_19: 1.0000
# Epoch 9/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.6044 - false_negatives_19: 3.0000 - false_positives_19: 178.0000 - true_negatives_19: 2.0000 - true_positives_19: 417.0000 - accuracy: 0.6983 - precision_19: 0.7008 - recall_19: 0.9929 - val_loss: 0.6072 - val_false_negatives_19: 0.0000e+00 - val_false_positives_19: 61.0000 - val_true_negatives_19: 0.0000e+00 - val_true_positives_19: 139.0000 - val_accuracy: 0.6950 - val_precision_19: 0.6950 - val_recall_19: 1.0000
# Epoch 10/15
# 3/3 [==============================] - 0s 55ms/step - loss: 0.5918 - false_negatives_19: 2.0000 - false_positives_19: 172.0000 - true_negatives_19: 8.0000 - true_positives_19: 418.0000 - accuracy: 0.7100 - precision_19: 0.7085 - recall_19: 0.9952 - val_loss: 0.5917 - val_false_negatives_19: 1.0000 - val_false_positives_19: 59.0000 - val_true_negatives_19: 2.0000 - val_true_positives_19: 138.0000 - val_accuracy: 0.7000 - val_precision_19: 0.7005 - val_recall_19: 0.9928
# Epoch 11/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5841 - false_negatives_19: 9.0000 - false_positives_19: 169.0000 - true_negatives_19: 11.0000 - true_positives_19: 411.0000 - accuracy: 0.7033 - precision_19: 0.7086 - recall_19: 0.9786 - val_loss: 0.5771 - val_false_negatives_19: 1.0000 - val_false_positives_19: 58.0000 - val_true_negatives_19: 3.0000 - val_true_positives_19: 138.0000 - val_accuracy: 0.7050 - val_precision_19: 0.7041 - val_recall_19: 0.9928
# Epoch 12/15
# 3/3 [==============================] - 0s 53ms/step - loss: 0.5664 - false_negatives_19: 11.0000 - false_positives_19: 158.0000 - true_negatives_19: 22.0000 - true_positives_19: 409.0000 - accuracy: 0.7183 - precision_19: 0.7213 - recall_19: 0.9738 - val_loss: 0.5644 - val_false_negatives_19: 3.0000 - val_false_positives_19: 57.0000 - val_true_negatives_19: 4.0000 - val_true_positives_19: 136.0000 - val_accuracy: 0.7000 - val_precision_19: 0.7047 - val_recall_19: 0.9784
# Epoch 13/15
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5648 - false_negatives_19: 19.0000 - false_positives_19: 152.0000 - true_negatives_19: 28.0000 - true_positives_19: 401.0000 - accuracy: 0.7150 - precision_19: 0.7251 - recall_19: 0.9548 - val_loss: 0.5539 - val_false_negatives_19: 7.0000 - val_false_positives_19: 55.0000 - val_true_negatives_19: 6.0000 - val_true_positives_19: 132.0000 - val_accuracy: 0.6900 - val_precision_19: 0.7059 - val_recall_19: 0.9496
# Epoch 14/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5461 - false_negatives_19: 16.0000 - false_positives_19: 142.0000 - true_negatives_19: 38.0000 - true_positives_19: 404.0000 - accuracy: 0.7367 - precision_19: 0.7399 - recall_19: 0.9619 - val_loss: 0.5453 - val_false_negatives_19: 9.0000 - val_false_positives_19: 53.0000 - val_true_negatives_19: 8.0000 - val_true_positives_19: 130.0000 - val_accuracy: 0.6900 - val_precision_19: 0.7104 - val_recall_19: 0.9353
# Epoch 15/15
# 3/3 [==============================] - 0s 51ms/step - loss: 0.5493 - false_negatives_19: 20.0000 - false_positives_19: 141.0000 - true_negatives_19: 39.0000 - true_positives_19: 400.0000 - accuracy: 0.7317 - precision_19: 0.7394 - recall_19: 0.9524 - val_loss: 0.5385 - val_false_negatives_19: 9.0000 - val_false_positives_19: 49.0000 - val_true_negatives_19: 12.0000 - val_true_positives_19: 130.0000 - val_accuracy: 0.7100 - val_precision_19: 0.7263 - val_recall_19: 0.9353
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 62ms/step
#
# Running the sensitivity analysis feature by feature. This might take a while.
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 159ms/step
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
#
# Data Computation Phase Completed Successfully.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.7s finished

# %%
# Saving the computed datasets. These are used in the analysis part of the tool
german_model_evaluation_df.round(2).to_csv(
    f"{german_output_folder_location}/ml_models_evaluation.csv", index=False,
)
german_raw_predictions_df.round(2).to_csv(
    f"{german_output_folder_location}/sensitivity_predictions_raw.csv", index=False,
)
german_predictions_change_df.round(2).to_csv(
    f"{german_output_folder_location}/sensitivity_predictions_change.csv", index=False,
)
german_volatility_df.round(2).to_csv(
    f"{german_output_folder_location}/sensitivity_predictions_volatility.csv", index=False,
)
german_sensitivity_evaluation_df.round(2).to_csv(
    f"{german_output_folder_location}/sensitivity_output_evaluation.csv", index=False,
)

# %%
# Run tool interaction
RunInteraction(german_dataset_csv_path, german_output, german_output_folder_location, german_verbose).main(german_credit_df)
# Out:
# Creating visualizations based on the computed datasets.
#
# Creating correlation plot.
#
# Creating delta bias plots.
#
# Creating sensitivity analysis plots.
#
# Visualization creation completed.

# %% [markdown]
# For the next part, have a look at the computed analysis. Feel free to refer to the analysis section of the tutorial for inspiration on what you can look out for.
#
# Feel free to also manually open the CSV and image files for this dataset. They are located under: ``ml_bias_explainability/scripts/data/3_german_credit``. The input dataset is called ``german_credit_data.csv`` and the output files are located inside the ``output`` folder.

# %%
# Space to add own code. Feel free to add more code boxes using the "+ Code" button at the top menu of the Notebook. 
# Feel free to write answers using Markdown, this can be done by using the "+ Text" buton at the top menu of the Notebook.
